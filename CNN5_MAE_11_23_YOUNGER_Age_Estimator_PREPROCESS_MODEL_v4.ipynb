# %% [markdown]
# <a href="https://colab.research.google.com/github/premonish/YOUNGER_deprecated/blob/main/CNN5_MAE_11_23_YOUNGER_Age_Estimator_PREPROCESS_MODEL_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **YOUNGER - Age Estimator:  Preprocessing & Modeling**
# ---

# %% [markdown]
# ###**Contents**

# %% [markdown]
# [**IV. PREPROCESSING**](#scrollTo=nAuKSR5HuQCy)
#
# * 4.1 Introduction
# * 4.2 Imports
# * 4.3 Load Data
# * 4.4 Transform Data
# * 4.5 Train/Test Split
#
# [**V. MODELING**](#scrollTo=QpXbL0ZoYSpN)
#
# * 5.1 CNN Architecture
# * 5.2 Transfer Learning
# * 5.3 Training the Model
# * 5.4 Model Performance
# * 5.5 Performance Visualization
# * 5.6 Unseen Data Test
#
# [**VI. SUMMARY**](#scrollTo=fRhrsD9SjrO7)
#
#
# [**VII. REFERENCES**](#scrollTo=tD6Lsmxlh3s8)
#
# [**VIII. APPENDIX**](#scrollTo=UhDT3ZLzzWxs)
#
# ---

# %% [markdown]
# # **IV. PREPROCESSING**

# %% [markdown]
# ##**4.1 Introduction**
#
# Previously, to create an age-predictor, we have completed a notebook to import data and explore its attributes: [Data Wrangling & Exploratory Data Analysis](https://github.com/premonish/YOUNGER/blob/main/notebooks/YOUNGER_Age_Estimator_WRANGLING_EDA_v2.ipynb). We took a close look at the metadata and plotted some histograms of the variable distributions. We transformed the data to extract the age of the primary face in each image from their date-of-birth and the date the photo was taken. We focused on extracting a long array of vectors of the pixel information per photo. We finished the previous phase by creating 2 arrays: 'matrix_x' with each row containing the (150,000+ pixel/image) data from each image in the dataset, and 'vector_y' containing the corresponding 'age' labels for the images.
#
# In this notebook, we will focus on Preprocessing & Modeling. In particular, we will use a Convolutional Neural Network, which is industry standard for Machine Learning image classification tasks due to its unmatched performance.
#
#
# ---

# %% [markdown]
# **Class Balance Note:**
# We decided to focus on predicting only the well represented age classes [8-80]. The dataset did not contain enough examples of other ages. Since the dataset had many examples for other ages, we decided to downsample to balance the classes.

# %% [markdown]
# **Historical Context**
# >
# > Image classification has been around for decades, however the field has been rapidly maturing in the last decade.  Since 2010, [ImageNet](https://https://en.wikipedia.org/wiki/ImageNet) Large Scale Visual Recognition Challenge (ILSVRC) is an annual competition where teams attempt to categorize thousands of images into 1,000 classes. In 2012, 'AlexNet' won the competition by a landslide and this is considered a pivotal moment in the history of deep learning, enabled by ingenious data scientists, a massive labeled dataset, and GPUs for training.

# %% [markdown]
# **PREPROCESSING** will be focused on three main sections.
#
# 1. Create Dummy Variables for categorical variables. (One-Hot Encoding)
# 2. Standardize the magnitude of numeric features using a scaler. (Scale 0-1)
# 3. Split data into testing and training datasets.
# ---

# %% [markdown]
# ## **4.2 Imports**

# %%
# !pip install tensorflow

# %%
# Create a list of currently installed python libraries for posterity
# !pip freeze > requirements.txt

# %%
### IMPORT libraries and packages ###
### I get by with a little help from my friends ###
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# deep-learning imports
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.layers import Dense, Activation, Dropout, Flatten, Input, Convolution2D, ZeroPadding2D, MaxPooling2D, Activation
from keras.layers import Conv2D, AveragePooling2D
from keras.models import Model, Sequential
from keras import metrics
from keras.models import model_from_json

# %%
# mount GDrive where the dataset is stored for Colab environment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **4.3 Load Data**
# Let's load the compressed numpy arrays from disk, extract data, and check the number of rows in our dataset.

# %%
# %%time
from numpy import asarray, savez_compressed, load
# load dict of arrays
images = np.load('/content/drive/MyDrive/YOUNGER/data5.npz', allow_pickle=True)
matrix_x = images.f.arr_0
X = matrix_x
X.shape
# Out:
# CPU times: user 12.7 s, sys: 1.62 s, total: 14.3 s
# Wall time: 14.3 s

# %%
# load the ages array 'vector_y'
ages = np.load('/content/drive/MyDrive/YOUNGER/data6.npz', allow_pickle=True)
vector_y = ages.f.arr_0
y = vector_y
y.shape
# Out:
# (5037,)

# %%
# check output matrix_x & vector_y shapes
# both matrix_x and vector_y are arrays of the same length 
assert vector_y.shape == matrix_x.shape

# %% [markdown]
# **NOTE:** I've run many tests to see how many images to include without overwhelming Google Colab's RAM.
#
# I have already upgraded to Colab Pro for this project and have been reaching the RAM limits

# %%
# Plot Age Distribution represented in the dataset
import seaborn as sns
plt.figure(figsize=(5, 3))
sns.histplot(y, color='green')
plt.title('Age Distribution')
plt.xlabel('age')
plt.ylabel('count');

# %% [markdown]
# **^ Notice the balanced classes of the input data achieved in preprocessing.**
#
# We decided to focus on predicting only the well represented age classes [8-80]. The dataset did not contain enough examples of other ages. Since the dataset had many examples for other ages, we decided to downsample to balance the classes.
#
# ---

# %% [markdown]
# ## **4.4 Transform Data**

# %% [markdown]
# **One-Hot Encoding**
#
# We need to encode the 'ages' label as categorical (binary) representations to prepare for machine learning.
# The Keras API provides a 'to_categorical()' method that can be used to one-hot encode integer data.

# %%
# classes = 101   # ages 0 to 100   # We didn't have enough training examples to predict 101 classes
classes = 73      # ages 8 to 80 (inclusive - inclusive)
target = y-8      # prepare for zero-indexed encoding - must add for prediction

# "Converts a class vector (integers) to binary class matrix." 
target_classes = keras.utils.to_categorical(target, classes)

# %% [markdown]
# **Reshaping the Data**
#
# We must reshape the data into the standard input array shape of a 'rank 4 tensor' to prepare for the Tensorflow CNN.
#
# (b, w, h, c) : (batch, width, height, channels)

# %%
features = []
for i in range(0, len(X)):
    features.append(X[i])
features = np.array(features)
features = features.reshape(len(X),224,224,3)
features.shape
# Out:
# (5037, 224, 224, 3)

# %% [markdown]
# **Scale the Data**
#
# Each of the pixel values range from 0-255. Let's scale the values to from 0-1 by dividing each value by 255. Interestingly, we are actually performing this operation virtually instantly 150,528 times per image (times the number of images).

# %%
features /= 255        # scale down pixel values to range [0, 1]
print("The maximum value in our dataset is:", features.max())
# Out:
# The maximum value in our dataset is: 1.0

# %% [markdown]
# ---

# %% [markdown]
# ## **4.5 Train/Test Split**
# We will divide the dataset randomly into training data and test data (80/20). We will later perform data augmentation on only the training set to help balance the classes of ages in the dataset.

# %%
# train/ test split
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(features, target_classes, test_size=0.30, random_state=42, stratify=target_classes)

# %%
print("X_train shape =" ,train_x.shape) 
print("X_test  shape ="  ,test_x.shape)
print('- - - - - - - - - - - - - - - - - -')
print("y_train shape =" ,train_y.shape)
print("y_test  shape ="  ,test_y.shape)
# Out:
# X_train shape = (3525, 224, 224, 3)
# X_test  shape = (1512, 224, 224, 3)
# - - - - - - - - - - - - - - - - - -
# y_train shape = (3525, 73)
# y_test  shape = (1512, 73)

# %% [markdown]
# Now that we have one-hot encoded the target classes, shaped the input data into tensor-like shapes, scaled the data to 0-1, and split the dataset into training and test subsets, we are ready to move onto modeling.

# %% [markdown]
# ---

# %% [markdown]
# # **V. MODELING**

# %% [markdown]
# **MODELING** will focus on the following four phases.
# 1. Train the models on the dataset (fit)
# 2. Review model performance metrics
# 3. Iterate over other models
# 4. Identify the final model
#
#
# ---

# %% [markdown]
# ## **5.1 CNN Architecture**
#
# I'll start by using an established architecture titled "[VGG-Face](https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf)" effective for facial recognition and building custom layers on top. This model was created by the Visual Geometry Group, at the University of Oxford to recognize 2,622 celebrities. Facial recognition is a more complex task than age prediction, yet the features extracted from many of the early layers of this model can be useful to our problem.
#
# "These models can be used for non-commercial research purposes under [Creative Commons Attribution License](https://creativecommons.org/licenses/by-nc/4.0/)."
#
# [VGGFace Github](https://github.com/rcmalli/keras-vggface)

# %% [markdown]
# ![vgg_arch.PNG](data:image/png;base64,...)

# %% [markdown]
# **^ VGG-Face Architecture** The first 8 blocks are convolutional. The last 3 blocks are Fully Connected (fc). All convolution layers are followed by a ReLU (recitified linear unit) activation later. A softmax layer predicts probabilities of the labels.

# %%
# from tensorflow.keras import layers
# data_augmentation = keras.Sequential(
#   [
#     layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(224,224,3)),
#     layers.experimental.preprocessing.RandomRotation(0.1),
#     layers.experimental.preprocessing.RandomZoom(0.1),
#   ]
# )

# %%
#VGG-Face model
# model = Sequential(data_augmentation)
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(224,224, 3)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(Convolution2D(4096, (7, 7), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(4096, (1, 1), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(2622, (1, 1)))
model.add(Flatten())
model.add(Activation('softmax'))

# %% [markdown]
# ---

# %% [markdown]
# ## **5.2 Transfer Learning**
#
# Transfer learning allows us to use weights that have already been trained on a massive dataset (2.6M images in this case). For similar tasks, we can simply freeze the weights for many of the early layers. However, the later layers in the model will need to trained and tuned for our specific task.
#
# **Trained weights source:**
# https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf

# %%
# load the pre-trained weights to take advantage of transfer learning
model.load_weights('/content/drive/MyDrive/YOUNGER/vgg_face_weights.h5')

# %% [markdown]
# **To take advantage of transfer learning, we will freeze layers with trained weights. We will custom tune the last four layers for our age predictor based on our training set.**

# %%
# freeze layers to use transfer learning effectively
for layer in model.layers[:-7]:
  layer.trainable = False

# add custom layers to predict on unique dataset and problem 
base_model_output = Sequential()
base_model_output = Convolution2D(73, (1, 1), name='predictions')(model.layers[-4].output)
base_model_output = Flatten()(base_model_output)
base_model_output = Activation('softmax')(base_model_output)
 
age_model = Model(inputs=model.input, outputs=base_model_output)

# %%
#check trainable layers
if False:
    for layer in model.layers:
        print(layer, layer.trainable)
    
    print("------------------------")
    for layer in age_model.layers:
        print(layer, layer.trainable)

# %% [markdown]
# **Compile Model**
#
# Categorical crossentropy is an appropriate loss function for multi-class classification problems.
#
# We will use an 'Adam' optimizer with a learning rate of 0.001.

# %%
# Stochastic Gradient Descent = sgd
# compile the model
# sgd = keras.optimizers.SGD(lr=1e-3, decay=1e-6, momentum=0.9, nesterov=True)
sgd = keras.optimizers.SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)

# opt = keras.optimizers.Adam(learning_rate=0.0007, #original 0.001
#     beta_1=0.9,
#     beta_2=0.999,
#     epsilon=1e-07,
#     name="Adam"
# )

# 'categorical_crossentropy' is an appropriate loss function for a multi-class classification problem such as ours
age_model.compile(loss='categorical_crossentropy'
                  # , optimizer = opt
                  , optimizer = sgd
                  , metrics=['accuracy']
                 )

# %% [markdown]
# **Model Checkpoint**
#
# Validation Loss is our key performance metric. We create a checkpointer which automatically saves the best model based on improved 'val_loss' performance. We can later use the best pre-trained model to measure the performance of the model on unseen data.

# %%
# # create checkpoint which saves the best model based on loss on the validation data 
# # if the validation loss decreases, the model will be saved as a checkpoint
# checkpointer = ModelCheckpoint(
#     # filepath='/content/classification_age_model.hdf5'
#     filepath='/content/drive/MyDrive/YOUNGER/classification_age_model_5.hdf5'
#     , monitor = "val_loss"
#     , verbose=1
#     , save_best_only=True
#     , mode = 'min'
#     # , mode = 'auto'
# )

# %% [markdown]
# **Early Stopping**
#
# Early Stopping will notice when the validation loss is not improving  and it will stop the training to prevent overfitting.

# %%
# # enable Early Stopping 
# from tensorflow.keras.callbacks import EarlyStopping
# callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5)

# %% [markdown]
# **Tensorboard**
#
# Tensorboard allows us to experiment, visualizing changes in model details (hyperparameters) and perfomance metrics.

# %%
#tensorboard
# %load_ext tensorboard
import datetime

# %%
# instantiate TensorBoard and define callback variable
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %% [markdown]
# **Save Performance Metrics**
#
# Kera's 'History' callback allows us to track performance metrics which we can later visualize.

# %%
# record model performance
from keras.callbacks import History 
history = History()

# %%
# Clear any logs from previous runs - TensorBoard
! rm -rf ./logs/

# %% [markdown]
# ---

# %% [markdown]
# ##**5.3 Training the Model**
#
# Training the model is where the magic happens. We will train our model for a given number of epochs with a given batchsize. We have tried many iterations with various batchsizes and various numbers of epochs to reach allow proper training while avoiding overfitting. Our primary performance metric is validation loss. As the model progresses through epochs, we want the validation loss to decrease at a steady pace.
#
# We will save our best model. In the future, we can simply use the saved model to predict on new data.

# %%
# set batch size and # of epochs
# fit the model on training set & validate on the test set
epochs = 200           # original = 250
batch_size = 128      # original = 256

enableFit = True

if enableFit:
    for i in range(epochs):
        print("epoch ",i)
        ix_train = np.random.choice(train_x.shape[0], size=batch_size)
        
        score = age_model.fit(
            train_x[ix_train], train_y[ix_train],
            epochs=1,
            validation_data=(test_x, test_y),
            callbacks=[history])
            # callbacks=[tensorboard_callback, checkpointer, callback, history])
        
#     #restore the best weights
#     from keras.models import load_model
#     age_model = load_model('/content/drive/MyDrive/YOUNGER/classification_age_model_5.hdf5')
#     age_model.save_weights('/content/drive/MyDrive/YOUNGER/age_model_weights_5.h5')
        
# else:
#     # pre-trained weights for age prediction
#     age_model.load_weights("/content/drive/MyDrive/YOUNGER/age_model_weights_5.h5")
# Out:
# epoch  0
# 4/4 [==============================] - 12s 2s/step - loss: 4.2957 - accuracy: 0.0000e+00 - val_loss: 4.2901 - val_accuracy: 0.0099
# epoch  1
# 4/4 [==============================] - 5s 2s/step - loss: 4.2863 - accuracy: 0.0156 - val_loss: 4.2890 - val_accuracy: 0.0192
# epoch  2
# 4/4 [==============================] - 5s 2s/step - loss: 4.2903 - accuracy: 0.0156 - val_loss: 4.2869 - val_accuracy: 0.0159
# epoch  3
# 4/4 [==============================] - 5s 2s/step - loss: 4.2780 - accuracy: 0.0469 - val_loss: 4.2842 - val_accuracy: 0.0159
# epoch  4
# 4/4 [==============================] - 5s 2s/step - loss: 4.2780 - accuracy: 0.0234 - val_loss: 4.2802 - val_accuracy: 0.0132
# epoch  5
# 4/4 [==============================] - 5s 2s/step - loss: 4.2709 - accuracy: 0.0312 - val_loss: 4.2749 - val_accuracy: 0.0132
# epoch  6
# 4/4 [==============================] - 5s 2s/step - loss: 4.2607 - accuracy: 0.0156 - val_loss: 4.2663 - val_accuracy: 0.0165
# epoch  7
# 4/4 [==============================] - 5s 2s/step - loss: 4.2558 - accuracy: 0.0156 - val_loss: 4.2533 - val_accuracy: 0.0258
# epoch  8
# 4/4 [==============================] - 5s 2s/step - loss: 4.2582 - accuracy: 0.0234 - val_loss: 4.2378 - val_accuracy: 0.0238
# epoch  9
# 4/4 [==============================] - 5s 2s/step - loss: 4.2213 - accuracy: 0.0156 - val_loss: 4.2075 - val_accuracy: 0.0357
# epoch  10
# 4/4 [==============================] - 5s 2s/step - loss: 4.1439 - accuracy: 0.0547 - val_loss: 4.1514 - val_accuracy: 0.0417
# epoch  11
# 4/4 [==============================] - 5s 2s/step - loss: 4.1269 - accuracy: 0.0312 - val_loss: 4.0850 - val_accuracy: 0.0390
# epoch  12
# 4/4 [==============================] - 5s 2s/step - loss: 4.0400 - accuracy: 0.0391 - val_loss: 4.0337 - val_accuracy: 0.0317
# epoch  13
# 4/4 [==============================] - 5s 2s/step - loss: 3.9554 - accuracy: 0.0156 - val_loss: 3.9880 - val_accuracy: 0.0364
# epoch  14
# 4/4 [==============================] - 5s 2s/step - loss: 3.9944 - accuracy: 0.0391 - val_loss: 3.9451 - val_accuracy: 0.0390
# epoch  15
# 4/4 [==============================] - 5s 2s/step - loss: 3.8842 - accuracy: 0.0312 - val_loss: 3.9461 - val_accuracy: 0.0430
# epoch  16
# 4/4 [==============================] - 5s 2s/step - loss: 3.7823 - accuracy: 0.0312 - val_loss: 3.8755 - val_accuracy: 0.0456
# epoch  17
# 4/4 [==============================] - 5s 2s/step - loss: 3.6977 - accuracy: 0.0938 - val_loss: 3.8659 - val_accuracy: 0.0437
# epoch  18
# 4/4 [==============================] - 5s 2s/step - loss: 3.6827 - accuracy: 0.0469 - val_loss: 3.9073 - val_accuracy: 0.0476
# epoch  19
# 4/4 [==============================] - 5s 2s/step - loss: 3.7871 - accuracy: 0.0938 - val_loss: 3.8770 - val_accuracy: 0.0503
# epoch  20
# 4/4 [==============================] - 5s 2s/step - loss: 3.7270 - accuracy: 0.0938 - val_loss: 3.8344 - val_accuracy: 0.0582
# epoch  21
# 4/4 [==============================] - 5s 2s/step - loss: 3.8893 - accuracy: 0.0391 - val_loss: 3.8879 - val_accuracy: 0.0483
# epoch  22
# 4/4 [==============================] - 5s 2s/step - loss: 3.7527 - accuracy: 0.0938 - val_loss: 3.8372 - val_accuracy: 0.0529
# epoch  23
# 4/4 [==============================] - 5s 2s/step - loss: 3.8065 - accuracy: 0.0391 - val_loss: 3.8344 - val_accuracy: 0.0450
# epoch  24
# 4/4 [==============================] - 5s 2s/step - loss: 3.8062 - accuracy: 0.0469 - val_loss: 3.8930 - val_accuracy: 0.0417
# epoch  25
# 4/4 [==============================] - 5s 2s/step - loss: 3.7613 - accuracy: 0.0469 - val_loss: 3.9452 - val_accuracy: 0.0397
# epoch  26
# 4/4 [==============================] - 5s 2s/step - loss: 3.7791 - accuracy: 0.1094 - val_loss: 3.8621 - val_accuracy: 0.0463
# epoch  27
# 4/4 [==============================] - 5s 2s/step - loss: 3.8716 - accuracy: 0.0703 - val_loss: 3.8266 - val_accuracy: 0.0423
# epoch  28
# 4/4 [==============================] - 5s 2s/step - loss: 3.8147 - accuracy: 0.0391 - val_loss: 3.8017 - val_accuracy: 0.0575
# epoch  29
# 4/4 [==============================] - 5s 2s/step - loss: 3.5749 - accuracy: 0.0859 - val_loss: 3.9111 - val_accuracy: 0.0403
# epoch  30
# 4/4 [==============================] - 5s 2s/step - loss: 3.8441 - accuracy: 0.0938 - val_loss: 3.7982 - val_accuracy: 0.0489
# epoch  31
# 4/4 [==============================] - 5s 2s/step - loss: 3.6930 - accuracy: 0.0859 - val_loss: 3.8168 - val_accuracy: 0.0615
# epoch  32
# 4/4 [==============================] - 5s 2s/step - loss: 3.7396 - accuracy: 0.0703 - val_loss: 3.7777 - val_accuracy: 0.0496
# epoch  33
# 4/4 [==============================] - 5s 2s/step - loss: 3.6288 - accuracy: 0.0859 - val_loss: 3.9359 - val_accuracy: 0.0476
# epoch  34
# 4/4 [==============================] - 5s 2s/step - loss: 3.6652 - accuracy: 0.0938 - val_loss: 3.8352 - val_accuracy: 0.0595
# epoch  35
# 4/4 [==============================] - 5s 2s/step - loss: 3.6111 - accuracy: 0.0859 - val_loss: 3.8639 - val_accuracy: 0.0423
# epoch  36
# 4/4 [==============================] - 5s 2s/step - loss: 3.7414 - accuracy: 0.0781 - val_loss: 3.8605 - val_accuracy: 0.0476
# epoch  37
# 4/4 [==============================] - 5s 2s/step - loss: 3.7020 - accuracy: 0.0469 - val_loss: 3.8213 - val_accuracy: 0.0556
# epoch  38
# 4/4 [==============================] - 5s 2s/step - loss: 3.7541 - accuracy: 0.0938 - val_loss: 3.8048 - val_accuracy: 0.0562
# epoch  39
# 4/4 [==============================] - 5s 2s/step - loss: 3.7971 - accuracy: 0.0312 - val_loss: 3.7731 - val_accuracy: 0.0470
# epoch  40
# 4/4 [==============================] - 5s 2s/step - loss: 3.7841 - accuracy: 0.0703 - val_loss: 3.7937 - val_accuracy: 0.0556
# epoch  41
# 4/4 [==============================] - 5s 2s/step - loss: 3.8598 - accuracy: 0.0625 - val_loss: 3.8663 - val_accuracy: 0.0509
# epoch  42
# 4/4 [==============================] - 5s 2s/step - loss: 3.7764 - accuracy: 0.0547 - val_loss: 3.7833 - val_accuracy: 0.0503
# epoch  43
# 4/4 [==============================] - 5s 2s/step - loss: 3.7221 - accuracy: 0.0469 - val_loss: 3.7875 - val_accuracy: 0.0569
# epoch  44
# 4/4 [==============================] - 5s 2s/step - loss: 3.5756 - accuracy: 0.1719 - val_loss: 3.7828 - val_accuracy: 0.0575
# epoch  45
# 4/4 [==============================] - 5s 2s/step - loss: 3.9086 - accuracy: 0.0781 - val_loss: 3.8377 - val_accuracy: 0.0476
# epoch  46
# 4/4 [==============================] - 5s 2s/step - loss: 3.6491 - accuracy: 0.0938 - val_loss: 3.7994 - val_accuracy: 0.0516
# epoch  47
# 4/4 [==============================] - 5s 2s/step - loss: 3.4702 - accuracy: 0.0625 - val_loss: 3.8498 - val_accuracy: 0.0556
# epoch  48
# 4/4 [==============================] - 5s 2s/step - loss: 3.6645 - accuracy: 0.0547 - val_loss: 3.8540 - val_accuracy: 0.0556
# epoch  49
# 4/4 [==============================] - 5s 2s/step - loss: 3.8027 - accuracy: 0.0625 - val_loss: 3.8063 - val_accuracy: 0.0456
# epoch  50
# 4/4 [==============================] - 5s 2s/step - loss: 3.5932 - accuracy: 0.0859 - val_loss: 3.7928 - val_accuracy: 0.0410
# epoch  51
# 4/4 [==============================] - 5s 2s/step - loss: 3.4531 - accuracy: 0.1484 - val_loss: 3.9206 - val_accuracy: 0.0542
# epoch  52
# 4/4 [==============================] - 5s 2s/step - loss: 3.7364 - accuracy: 0.0938 - val_loss: 3.9024 - val_accuracy: 0.0430
# epoch  53
# 4/4 [==============================] - 5s 2s/step - loss: 3.7532 - accuracy: 0.0625 - val_loss: 3.8032 - val_accuracy: 0.0470
# epoch  54
# 4/4 [==============================] - 5s 2s/step - loss: 3.6302 - accuracy: 0.0781 - val_loss: 3.8445 - val_accuracy: 0.0496
# epoch  55
# 4/4 [==============================] - 5s 2s/step - loss: 3.7705 - accuracy: 0.0703 - val_loss: 3.8516 - val_accuracy: 0.0437
# epoch  56
# 4/4 [==============================] - 5s 2s/step - loss: 3.8545 - accuracy: 0.0625 - val_loss: 3.8364 - val_accuracy: 0.0575
# epoch  57
# 4/4 [==============================] - 5s 2s/step - loss: 3.7063 - accuracy: 0.0781 - val_loss: 3.8371 - val_accuracy: 0.0450
# epoch  58
# 4/4 [==============================] - 5s 2s/step - loss: 3.6930 - accuracy: 0.0703 - val_loss: 3.8070 - val_accuracy: 0.0562
# epoch  59
# 4/4 [==============================] - 5s 2s/step - loss: 3.6073 - accuracy: 0.1172 - val_loss: 3.8524 - val_accuracy: 0.0410
# epoch  60
# 4/4 [==============================] - 5s 2s/step - loss: 3.6925 - accuracy: 0.0938 - val_loss: 3.8205 - val_accuracy: 0.0608
# epoch  61
# 4/4 [==============================] - 5s 2s/step - loss: 3.7093 - accuracy: 0.0938 - val_loss: 3.8036 - val_accuracy: 0.0549
# epoch  62
# 4/4 [==============================] - 5s 2s/step - loss: 3.5909 - accuracy: 0.1016 - val_loss: 3.8219 - val_accuracy: 0.0589
# epoch  63
# 4/4 [==============================] - 5s 2s/step - loss: 3.6990 - accuracy: 0.0703 - val_loss: 3.8632 - val_accuracy: 0.0542
# epoch  64
# 4/4 [==============================] - 5s 2s/step - loss: 3.7559 - accuracy: 0.0703 - val_loss: 3.8058 - val_accuracy: 0.0483
# epoch  65
# 4/4 [==============================] - 5s 2s/step - loss: 3.7551 - accuracy: 0.0547 - val_loss: 3.8357 - val_accuracy: 0.0582
# epoch  66
# 4/4 [==============================] - 5s 2s/step - loss: 3.5596 - accuracy: 0.1250 - val_loss: 3.8053 - val_accuracy: 0.0556
# epoch  67
# 4/4 [==============================] - 5s 2s/step - loss: 3.4769 - accuracy: 0.1172 - val_loss: 3.8625 - val_accuracy: 0.0608
# epoch  68
# 4/4 [==============================] - 5s 2s/step - loss: 3.7925 - accuracy: 0.1016 - val_loss: 3.7910 - val_accuracy: 0.0675
# epoch  69
# 4/4 [==============================] - 5s 2s/step - loss: 3.7424 - accuracy: 0.0859 - val_loss: 3.7956 - val_accuracy: 0.0483
# epoch  70
# 4/4 [==============================] - 5s 2s/step - loss: 3.4846 - accuracy: 0.1328 - val_loss: 3.9321 - val_accuracy: 0.0370
# epoch  71
# 4/4 [==============================] - 5s 2s/step - loss: 3.7978 - accuracy: 0.1328 - val_loss: 3.7724 - val_accuracy: 0.0529
# epoch  72
# 4/4 [==============================] - 5s 2s/step - loss: 3.5784 - accuracy: 0.1016 - val_loss: 3.7800 - val_accuracy: 0.0542
# epoch  73
# 4/4 [==============================] - 5s 2s/step - loss: 3.5216 - accuracy: 0.1094 - val_loss: 3.7740 - val_accuracy: 0.0516
# epoch  74
# 4/4 [==============================] - 5s 2s/step - loss: 3.5152 - accuracy: 0.0781 - val_loss: 3.8588 - val_accuracy: 0.0556
# epoch  75
# 4/4 [==============================] - 5s 2s/step - loss: 3.6035 - accuracy: 0.0781 - val_loss: 3.8436 - val_accuracy: 0.0542
# epoch  76
# 4/4 [==============================] - 5s 2s/step - loss: 3.5288 - accuracy: 0.0781 - val_loss: 3.8332 - val_accuracy: 0.0542
# epoch  77
# 4/4 [==============================] - 5s 2s/step - loss: 3.6864 - accuracy: 0.0781 - val_loss: 3.7932 - val_accuracy: 0.0509
# epoch  78
# 4/4 [==============================] - 5s 2s/step - loss: 3.6119 - accuracy: 0.1172 - val_loss: 3.7843 - val_accuracy: 0.0496
# epoch  79
# 4/4 [==============================] - 5s 2s/step - loss: 3.7883 - accuracy: 0.0859 - val_loss: 3.8019 - val_accuracy: 0.0503
# epoch  80
# 4/4 [==============================] - 5s 2s/step - loss: 3.5770 - accuracy: 0.1016 - val_loss: 3.8645 - val_accuracy: 0.0615
# epoch  81
# 4/4 [==============================] - 5s 2s/step - loss: 3.7173 - accuracy: 0.0703 - val_loss: 3.8821 - val_accuracy: 0.0575
# epoch  82
# 4/4 [==============================] - 5s 2s/step - loss: 3.7226 - accuracy: 0.0703 - val_loss: 3.9066 - val_accuracy: 0.0450
# epoch  83
# 4/4 [==============================] - 5s 2s/step - loss: 3.7604 - accuracy: 0.0703 - val_loss: 3.8223 - val_accuracy: 0.0622
# epoch  84
# 4/4 [==============================] - 5s 2s/step - loss: 3.4841 - accuracy: 0.1172 - val_loss: 3.8354 - val_accuracy: 0.0549
# epoch  85
# 4/4 [==============================] - 5s 2s/step - loss: 3.6267 - accuracy: 0.0781 - val_loss: 3.8536 - val_accuracy: 0.0556
# epoch  86
# 4/4 [==============================] - 5s 2s/step - loss: 3.6535 - accuracy: 0.0703 - val_loss: 3.9493 - val_accuracy: 0.0536
# epoch  87
# 4/4 [==============================] - 5s 2s/step - loss: 3.6311 - accuracy: 0.1016 - val_loss: 3.8044 - val_accuracy: 0.0608
# epoch  88
# 4/4 [==============================] - 5s 2s/step - loss: 3.4905 - accuracy: 0.0625 - val_loss: 3.8709 - val_accuracy: 0.0602
# epoch  89
# 4/4 [==============================] - 5s 2s/step - loss: 3.5647 - accuracy: 0.0938 - val_loss: 3.8358 - val_accuracy: 0.0516
# epoch  90
# 4/4 [==============================] - 5s 2s/step - loss: 3.5823 - accuracy: 0.1250 - val_loss: 3.8487 - val_accuracy: 0.0463
# epoch  91
# 4/4 [==============================] - 5s 2s/step - loss: 3.5498 - accuracy: 0.1016 - val_loss: 3.8904 - val_accuracy: 0.0509
# epoch  92
# 4/4 [==============================] - 5s 2s/step - loss: 3.6224 - accuracy: 0.0859 - val_loss: 3.8776 - val_accuracy: 0.0503
# epoch  93
# 4/4 [==============================] - 5s 2s/step - loss: 3.7681 - accuracy: 0.1094 - val_loss: 3.8673 - val_accuracy: 0.0470
# epoch  94
# 4/4 [==============================] - 5s 2s/step - loss: 3.5400 - accuracy: 0.1484 - val_loss: 3.8870 - val_accuracy: 0.0496
# epoch  95
# 4/4 [==============================] - 5s 2s/step - loss: 3.6715 - accuracy: 0.1172 - val_loss: 3.9075 - val_accuracy: 0.0430
# epoch  96
# 4/4 [==============================] - 5s 2s/step - loss: 3.6107 - accuracy: 0.1250 - val_loss: 3.9198 - val_accuracy: 0.0503
# epoch  97
# 4/4 [==============================] - 5s 2s/step - loss: 3.5672 - accuracy: 0.1484 - val_loss: 3.8913 - val_accuracy: 0.0582
# epoch  98
# 4/4 [==============================] - 5s 2s/step - loss: 3.7644 - accuracy: 0.1016 - val_loss: 3.8684 - val_accuracy: 0.0542
# epoch  99
# 4/4 [==============================] - 5s 2s/step - loss: 3.4991 - accuracy: 0.1484 - val_loss: 3.8543 - val_accuracy: 0.0575
# epoch  100
# 4/4 [==============================] - 5s 2s/step - loss: 3.6592 - accuracy: 0.1250 - val_loss: 3.8530 - val_accuracy: 0.0575
# epoch  101
# 4/4 [==============================] - 5s 2s/step - loss: 3.5157 - accuracy: 0.1016 - val_loss: 3.8050 - val_accuracy: 0.0496
# epoch  102
# 4/4 [==============================] - 5s 2s/step - loss: 3.7395 - accuracy: 0.0781 - val_loss: 3.8331 - val_accuracy: 0.0483
# epoch  103
# 4/4 [==============================] - 5s 2s/step - loss: 3.7352 - accuracy: 0.1328 - val_loss: 3.7924 - val_accuracy: 0.0582
# epoch  104
# 4/4 [==============================] - 5s 2s/step - loss: 3.6407 - accuracy: 0.1250 - val_loss: 3.8411 - val_accuracy: 0.0536
# epoch  105
# 4/4 [==============================] - 5s 2s/step - loss: 3.5776 - accuracy: 0.0938 - val_loss: 3.9223 - val_accuracy: 0.0582
# epoch  106
# 4/4 [==============================] - 5s 2s/step - loss: 3.8310 - accuracy: 0.0859 - val_loss: 3.8502 - val_accuracy: 0.0661
# epoch  107
# 4/4 [==============================] - 5s 2s/step - loss: 3.5760 - accuracy: 0.1172 - val_loss: 3.9110 - val_accuracy: 0.0595
# epoch  108
# 4/4 [==============================] - 5s 2s/step - loss: 3.7405 - accuracy: 0.1328 - val_loss: 3.8412 - val_accuracy: 0.0602
# epoch  109
# 4/4 [==============================] - 5s 2s/step - loss: 3.6612 - accuracy: 0.1250 - val_loss: 3.8767 - val_accuracy: 0.0463
# epoch  110
# 4/4 [==============================] - 5s 2s/step - loss: 3.7152 - accuracy: 0.1094 - val_loss: 3.8662 - val_accuracy: 0.0556
# epoch  111
# 4/4 [==============================] - 5s 2s/step - loss: 3.5710 - accuracy: 0.1172 - val_loss: 3.8916 - val_accuracy: 0.0509
# epoch  112
# 4/4 [==============================] - 5s 2s/step - loss: 3.5669 - accuracy: 0.1016 - val_loss: 3.8734 - val_accuracy: 0.0516
# epoch  113
# 4/4 [==============================] - 5s 2s/step - loss: 3.6559 - accuracy: 0.1016 - val_loss: 3.8921 - val_accuracy: 0.0423
# epoch  114
# 4/4 [==============================] - 5s 2s/step - loss: 3.6583 - accuracy: 0.1016 - val_loss: 3.8934 - val_accuracy: 0.0489
# epoch  115
# 4/4 [==============================] - 5s 2s/step - loss: 3.3940 - accuracy: 0.1562 - val_loss: 3.9200 - val_accuracy: 0.0450
# epoch  116
# 4/4 [==============================] - 5s 2s/step - loss: 3.6965 - accuracy: 0.1094 - val_loss: 3.9633 - val_accuracy: 0.0437
# epoch  117
# 4/4 [==============================] - 5s 2s/step - loss: 3.6322 - accuracy: 0.1172 - val_loss: 3.9089 - val_accuracy: 0.0463
# epoch  118
# 4/4 [==============================] - 5s 2s/step - loss: 3.5599 - accuracy: 0.1172 - val_loss: 3.8958 - val_accuracy: 0.0483
# epoch  119
# 4/4 [==============================] - 5s 2s/step - loss: 3.6752 - accuracy: 0.1094 - val_loss: 3.9070 - val_accuracy: 0.0377
# epoch  120
# 4/4 [==============================] - 5s 2s/step - loss: 3.6344 - accuracy: 0.0859 - val_loss: 3.8788 - val_accuracy: 0.0450
# epoch  121
# 4/4 [==============================] - 5s 2s/step - loss: 3.6953 - accuracy: 0.1094 - val_loss: 3.8479 - val_accuracy: 0.0516
# epoch  122
# 4/4 [==============================] - 5s 2s/step - loss: 3.6814 - accuracy: 0.0859 - val_loss: 3.8234 - val_accuracy: 0.0602
# epoch  123
# 4/4 [==============================] - 5s 2s/step - loss: 3.5078 - accuracy: 0.1250 - val_loss: 3.8753 - val_accuracy: 0.0496
# epoch  124
# 4/4 [==============================] - 5s 2s/step - loss: 3.7577 - accuracy: 0.1250 - val_loss: 3.8876 - val_accuracy: 0.0503
# epoch  125
# 4/4 [==============================] - 5s 2s/step - loss: 3.4743 - accuracy: 0.1641 - val_loss: 3.9238 - val_accuracy: 0.0542
# epoch  126
# 4/4 [==============================] - 5s 2s/step - loss: 3.4858 - accuracy: 0.0938 - val_loss: 3.9513 - val_accuracy: 0.0476
# epoch  127
# 4/4 [==============================] - 5s 2s/step - loss: 3.7835 - accuracy: 0.1016 - val_loss: 3.8601 - val_accuracy: 0.0608
# epoch  128
# 4/4 [==============================] - 5s 2s/step - loss: 3.6663 - accuracy: 0.1094 - val_loss: 3.8992 - val_accuracy: 0.0483
# epoch  129
# 4/4 [==============================] - 5s 2s/step - loss: 3.6328 - accuracy: 0.0703 - val_loss: 3.9485 - val_accuracy: 0.0522
# epoch  130
# 4/4 [==============================] - 5s 2s/step - loss: 3.8459 - accuracy: 0.1094 - val_loss: 3.8904 - val_accuracy: 0.0476
# epoch  131
# 4/4 [==============================] - 5s 2s/step - loss: 3.5338 - accuracy: 0.1406 - val_loss: 3.8995 - val_accuracy: 0.0496
# epoch  132
# 4/4 [==============================] - 5s 2s/step - loss: 3.7574 - accuracy: 0.1406 - val_loss: 3.8354 - val_accuracy: 0.0463
# epoch  133
# 4/4 [==============================] - 5s 2s/step - loss: 3.7613 - accuracy: 0.1328 - val_loss: 3.8924 - val_accuracy: 0.0569
# epoch  134
# 4/4 [==============================] - 5s 2s/step - loss: 3.5707 - accuracy: 0.1172 - val_loss: 3.9093 - val_accuracy: 0.0536
# epoch  135
# 4/4 [==============================] - 5s 2s/step - loss: 3.5433 - accuracy: 0.1875 - val_loss: 3.8677 - val_accuracy: 0.0556
# epoch  136
# 4/4 [==============================] - 5s 2s/step - loss: 3.6186 - accuracy: 0.1328 - val_loss: 3.9271 - val_accuracy: 0.0470
# epoch  137
# 4/4 [==============================] - 5s 2s/step - loss: 3.7264 - accuracy: 0.1406 - val_loss: 3.8922 - val_accuracy: 0.0516
# epoch  138
# 4/4 [==============================] - 5s 2s/step - loss: 3.4721 - accuracy: 0.1562 - val_loss: 3.9173 - val_accuracy: 0.0582
# epoch  139
# 4/4 [==============================] - 5s 2s/step - loss: 3.6668 - accuracy: 0.1250 - val_loss: 3.8952 - val_accuracy: 0.0450
# epoch  140
# 4/4 [==============================] - 5s 2s/step - loss: 3.5133 - accuracy: 0.1328 - val_loss: 3.8913 - val_accuracy: 0.0542
# epoch  141
# 4/4 [==============================] - 5s 2s/step - loss: 3.6872 - accuracy: 0.1484 - val_loss: 3.9204 - val_accuracy: 0.0489
# epoch  142
# 4/4 [==============================] - 5s 2s/step - loss: 3.7128 - accuracy: 0.1484 - val_loss: 3.8603 - val_accuracy: 0.0529
# epoch  143
# 4/4 [==============================] - 5s 2s/step - loss: 3.6603 - accuracy: 0.1641 - val_loss: 3.8347 - val_accuracy: 0.0569
# epoch  144
# 4/4 [==============================] - 5s 2s/step - loss: 3.4815 - accuracy: 0.1797 - val_loss: 3.9382 - val_accuracy: 0.0503
# epoch  145
# 4/4 [==============================] - 5s 2s/step - loss: 3.4143 - accuracy: 0.1641 - val_loss: 3.8447 - val_accuracy: 0.0549
# epoch  146
# 4/4 [==============================] - 5s 2s/step - loss: 3.6915 - accuracy: 0.1328 - val_loss: 3.8761 - val_accuracy: 0.0582
# epoch  147
# 4/4 [==============================] - 5s 2s/step - loss: 3.7295 - accuracy: 0.1328 - val_loss: 3.8655 - val_accuracy: 0.0569
# epoch  148
# 4/4 [==============================] - 5s 2s/step - loss: 3.4566 - accuracy: 0.1250 - val_loss: 3.8631 - val_accuracy: 0.0542
# epoch  149
# 4/4 [==============================] - 5s 2s/step - loss: 3.6874 - accuracy: 0.0938 - val_loss: 3.8409 - val_accuracy: 0.0608
# epoch  150
# 4/4 [==============================] - 5s 2s/step - loss: 3.6424 - accuracy: 0.1172 - val_loss: 3.8713 - val_accuracy: 0.0450
# epoch  151
# 4/4 [==============================] - 5s 2s/step - loss: 3.8302 - accuracy: 0.1250 - val_loss: 3.8769 - val_accuracy: 0.0556
# epoch  152
# 4/4 [==============================] - 5s 2s/step - loss: 3.5602 - accuracy: 0.1484 - val_loss: 3.9554 - val_accuracy: 0.0522
# epoch  153
# 4/4 [==============================] - 5s 2s/step - loss: 3.7287 - accuracy: 0.1094 - val_loss: 3.9158 - val_accuracy: 0.0522
# epoch  154
# 4/4 [==============================] - 5s 2s/step - loss: 3.7362 - accuracy: 0.1250 - val_loss: 3.8755 - val_accuracy: 0.0516
# epoch  155
# 4/4 [==============================] - 5s 2s/step - loss: 3.4828 - accuracy: 0.1172 - val_loss: 3.8403 - val_accuracy: 0.0503
# epoch  156
# 4/4 [==============================] - 5s 2s/step - loss: 3.6667 - accuracy: 0.1250 - val_loss: 3.8592 - val_accuracy: 0.0562
# epoch  157
# 4/4 [==============================] - 5s 2s/step - loss: 3.5809 - accuracy: 0.1328 - val_loss: 3.8667 - val_accuracy: 0.0450
# epoch  158
# 4/4 [==============================] - 5s 2s/step - loss: 3.7866 - accuracy: 0.0938 - val_loss: 3.8646 - val_accuracy: 0.0556
# epoch  159
# 4/4 [==============================] - 5s 2s/step - loss: 3.3587 - accuracy: 0.1406 - val_loss: 3.8730 - val_accuracy: 0.0549
# epoch  160
# 4/4 [==============================] - 5s 2s/step - loss: 3.7216 - accuracy: 0.1406 - val_loss: 3.8907 - val_accuracy: 0.0489
# epoch  161
# 4/4 [==============================] - 5s 2s/step - loss: 3.6191 - accuracy: 0.1562 - val_loss: 3.9229 - val_accuracy: 0.0496
# epoch  162
# 4/4 [==============================] - 5s 2s/step - loss: 3.8544 - accuracy: 0.1562 - val_loss: 3.8909 - val_accuracy: 0.0456
# epoch  163
# 4/4 [==============================] - 5s 2s/step - loss: 3.6198 - accuracy: 0.1406 - val_loss: 3.9093 - val_accuracy: 0.0589
# epoch  164
# 4/4 [==============================] - 5s 2s/step - loss: 3.7391 - accuracy: 0.1328 - val_loss: 3.9791 - val_accuracy: 0.0556
# epoch  165
# 4/4 [==============================] - 5s 2s/step - loss: 3.8123 - accuracy: 0.1328 - val_loss: 3.9636 - val_accuracy: 0.0503
# epoch  166
# 4/4 [==============================] - 5s 2s/step - loss: 3.3899 - accuracy: 0.1641 - val_loss: 3.9088 - val_accuracy: 0.0595
# epoch  167
# 4/4 [==============================] - 5s 2s/step - loss: 3.8240 - accuracy: 0.1094 - val_loss: 3.9223 - val_accuracy: 0.0509
# epoch  168
# 4/4 [==============================] - 5s 2s/step - loss: 3.7271 - accuracy: 0.1172 - val_loss: 3.8689 - val_accuracy: 0.0522
# epoch  169
# 4/4 [==============================] - 5s 2s/step - loss: 3.8940 - accuracy: 0.1016 - val_loss: 3.8889 - val_accuracy: 0.0522
# epoch  170
# 4/4 [==============================] - 5s 2s/step - loss: 3.3522 - accuracy: 0.1797 - val_loss: 3.9074 - val_accuracy: 0.0529
# epoch  171
# 4/4 [==============================] - 5s 2s/step - loss: 3.8316 - accuracy: 0.1094 - val_loss: 3.8948 - val_accuracy: 0.0516
# epoch  172
# 4/4 [==============================] - 5s 2s/step - loss: 3.5634 - accuracy: 0.1250 - val_loss: 3.9299 - val_accuracy: 0.0575
# epoch  173
# 4/4 [==============================] - 5s 2s/step - loss: 3.6900 - accuracy: 0.1406 - val_loss: 3.9219 - val_accuracy: 0.0556
# epoch  174
# 4/4 [==============================] - 5s 2s/step - loss: 3.6972 - accuracy: 0.1172 - val_loss: 3.9342 - val_accuracy: 0.0529
# epoch  175
# 4/4 [==============================] - 5s 2s/step - loss: 3.7442 - accuracy: 0.0938 - val_loss: 3.8848 - val_accuracy: 0.0516
# epoch  176
# 4/4 [==============================] - 5s 2s/step - loss: 3.4799 - accuracy: 0.1641 - val_loss: 3.9289 - val_accuracy: 0.0463
# epoch  177
# 4/4 [==============================] - 5s 2s/step - loss: 3.6374 - accuracy: 0.1484 - val_loss: 3.8455 - val_accuracy: 0.0549
# epoch  178
# 4/4 [==============================] - 5s 2s/step - loss: 3.6062 - accuracy: 0.1016 - val_loss: 3.8718 - val_accuracy: 0.0536
# epoch  179
# 4/4 [==============================] - 5s 2s/step - loss: 3.8267 - accuracy: 0.1094 - val_loss: 3.9085 - val_accuracy: 0.0489
# epoch  180
# 4/4 [==============================] - 5s 2s/step - loss: 3.5859 - accuracy: 0.1406 - val_loss: 3.9305 - val_accuracy: 0.0456
# epoch  181
# 4/4 [==============================] - 5s 2s/step - loss: 3.8959 - accuracy: 0.0703 - val_loss: 3.8761 - val_accuracy: 0.0470
# epoch  182
# 4/4 [==============================] - 5s 2s/step - loss: 3.6722 - accuracy: 0.1406 - val_loss: 3.8706 - val_accuracy: 0.0589
# epoch  183
# 4/4 [==============================] - 5s 2s/step - loss: 3.7626 - accuracy: 0.1328 - val_loss: 3.8807 - val_accuracy: 0.0489
# epoch  184
# 4/4 [==============================] - 5s 2s/step - loss: 3.7464 - accuracy: 0.0938 - val_loss: 3.9390 - val_accuracy: 0.0496
# epoch  185
# 4/4 [==============================] - 5s 2s/step - loss: 3.4538 - accuracy: 0.1875 - val_loss: 3.9795 - val_accuracy: 0.0496
# epoch  186
# 4/4 [==============================] - 5s 2s/step - loss: 3.5159 - accuracy: 0.1406 - val_loss: 3.9436 - val_accuracy: 0.0476
# epoch  187
# 4/4 [==============================] - 5s 2s/step - loss: 3.7194 - accuracy: 0.0938 - val_loss: 3.9249 - val_accuracy: 0.0582
# epoch  188
# 4/4 [==============================] - 5s 2s/step - loss: 3.6850 - accuracy: 0.1641 - val_loss: 3.9505 - val_accuracy: 0.0489
# epoch  189
# 4/4 [==============================] - 5s 2s/step - loss: 3.6156 - accuracy: 0.1484 - val_loss: 3.9000 - val_accuracy: 0.0509
# epoch  190
# 4/4 [==============================] - 5s 2s/step - loss: 3.7886 - accuracy: 0.1406 - val_loss: 3.9099 - val_accuracy: 0.0522
# epoch  191
# 4/4 [==============================] - 5s 2s/step - loss: 3.7256 - accuracy: 0.1484 - val_loss: 3.8982 - val_accuracy: 0.0509
# epoch  192
# 4/4 [==============================] - 5s 2s/step - loss: 3.4949 - accuracy: 0.1562 - val_loss: 3.8865 - val_accuracy: 0.0496
# epoch  193
# 4/4 [==============================] - 5s 2s/step - loss: 3.6433 - accuracy: 0.1484 - val_loss: 3.9100 - val_accuracy: 0.0509
# epoch  194
# 4/4 [==============================] - 5s 2s/step - loss: 4.1299 - accuracy: 0.0859 - val_loss: 3.9057 - val_accuracy: 0.0503
# epoch  195
# 4/4 [==============================] - 5s 2s/step - loss: 3.8738 - accuracy: 0.0859 - val_loss: 3.9339 - val_accuracy: 0.0529
# epoch  196
# 4/4 [==============================] - 5s 2s/step - loss: 3.6420 - accuracy: 0.1250 - val_loss: 3.9363 - val_accuracy: 0.0556
# epoch  197
# 4/4 [==============================] - 5s 2s/step - loss: 3.5068 - accuracy: 0.2109 - val_loss: 3.8982 - val_accuracy: 0.0489
# epoch  198
# 4/4 [==============================] - 5s 2s/step - loss: 3.8980 - accuracy: 0.0469 - val_loss: 3.8971 - val_accuracy: 0.0443
# epoch  199
# 4/4 [==============================] - 5s 2s/step - loss: 3.7064 - accuracy: 0.1250 - val_loss: 3.9230 - val_accuracy: 0.0470

# %% [markdown]
# ---

# %% [markdown]
# ##**5.4 Model Performance**
#
# We will assess the performance of the model by plotting the **validation set loss versus the training set loss**. If the performance of the training set improves too fast and diverges from the validation set, this is a sign of overfitting. Our objective is to prevent overfitting, thus making the model more robust to unseen data.

# %%
# plot training loss vs. validation loss over epochs
val_loss_change = []; loss_change = []
for i in range(0, epochs):
    val_loss_change.append(history.history['val_loss'][i])
    loss_change.append(history.history['loss'][i])

plt.plot(val_loss_change, label='val_loss')
plt.plot(loss_change, label='train_loss')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# We will also assess the performance of the model by plotting the **validation set accuracy versus the training set accuracy**.

# %%
# plot training loss vs. validation loss over epochs
val_accuracy_change = []; accuracy_change = []
for i in range(0, epochs):
    val_accuracy_change.append(history.history['val_accuracy'][i])
    accuracy_change.append(history.history['accuracy'][i])

plt.plot(val_accuracy_change, label='val_accuracy')
plt.plot(accuracy_change, label='train_accuracy')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# **Check the training set loss and accuracy.**

# %%
# loss and accuracy on training set
train_eval = age_model.evaluate(train_x, train_y, verbose=1 , return_dict=True)
train_eval
# Out:
# 111/111 [==============================] - 12s 105ms/step - loss: 3.2786 - accuracy: 0.2048
# {'accuracy': 0.20482268929481506, 'loss': 3.2786285877227783}

# %% [markdown]
# **Check the test set loss and accuracy.**

# %%
# loss and accuracy on test set
test_eval = age_model.evaluate(test_x, test_y, verbose=1 , return_dict=True)
test_eval
# Out:
# 48/48 [==============================] - 5s 98ms/step - loss: 3.9230 - accuracy: 0.0470
# {'accuracy': 0.04695767164230347, 'loss': 3.9230310916900635}

# %% [markdown]
# **Predictions on the test set.**

# %%
predictions = age_model.predict(test_x)

# %% [markdown]
# **The array of predictions need to be decoded into predicted ages.**

# %%
output_indexes = np.array([i for i in range(8, 81)])
apparent_predictions = np.sum(predictions * output_indexes, axis = 1)

# %% [markdown]
# **Let's take a look at the maximum, minimum and mean age predictions to ensure that our distribution of values is what we expected.**

# %%
prediction_list = []
for i in range(73):
  prediction_list.append((np.argmax(predictions[i] * output_indexes[i])+8))

print("Minumum Predicted Age:",min(prediction_list))
print("Maximum Predicted Age:",max(prediction_list))
print("Average Predicted Age:",np.mean(prediction_list))
# Out:
# Minumum Predicted Age: 8
# Maximum Predicted Age: 78
# Average Predicted Age: 44.71232876712329

# %% [markdown]
# **Mean Absolute Error**
#
# Compute the Mean Absolute Error (MAE) to see how far the predicted ages are from the actual ages on average. MAE is the primary performance metric of our project.

# %%
# compute mae
mae_sum = 0
errors = []
n = apparent_predictions.shape[0]
prediction_list = []
for i in range(n):
    prediction = apparent_predictions[i]
    actual = np.argmax(test_y[i]) + 8
    mae_sum += abs(actual  - prediction)

    prediction_list.append(int(apparent_predictions[i])) # create a prediction list to plot
    errors.append((np.argmax(test_y[i]) + 8) - apparent_predictions[i])

mae = mae_sum / n
print("mae: ",mae)
print("instances: ", n)
# Out:
# mae:  11.228196196897352
# instances:  1512

# %%
# visualize the actual vs predicted age error distribution 
positive_errors = [i for i in errors if i > 0]
negative_errors = [i for i in errors if i < 0]

fig, ax = plt.subplots(figsize=(5,5))
sns.set_theme(style="darkgrid")
sns.histplot(positive_errors, color='blue', alpha=.8)
sns.histplot(negative_errors, color='red', alpha=.8)
plt.title('Error Distribution')
plt.xlabel('Error');

# %% [markdown]
# **Mean Absolute Percentage Error**
#
# Compute the Mean Absolute Percentage Error (MAPE) to see how far the predicted ages are from the actual ages on average as a percentage.

# %%
# calculate MAPE
mape_sum = 0
n = apparent_predictions.shape[0]
for i in range(n): 
  mape_sum += (abs((np.argmax(test_y[i])+8) - (apparent_predictions[i]+.000001))/(np.argmax(test_y[i])+8) )
mape = (mape_sum/n) 

print(mape)
print('MAPE:',(round(mape*100,2)),"%")
# Out:
# 0.4443392783903717
# MAPE: 44.43 %

# %%
# create list 'test_y_age'  of the actual age labels
test_y_age = np.argmax(test_y, axis=1)
test_y_age = test_y_age + 8

# %%
apparent_predictions_int = [round(i) for i in apparent_predictions]

# %%
listed_error = []
numb = len(apparent_predictions)
for i in range(numb):
  listed_error.append(abs(apparent_predictions[i] - test_y_age[i]))

sum(listed_error)/numb
# Out:
# 11.228196196897352

# %%
###
###
from sklearn import metrics
from sklearn.metrics import balanced_accuracy_score, f1_score, log_loss, accuracy_score, recall_score, confusion_matrix, mean_absolute_error
# bas = balanced_accuracy_score(test_y_age, apparent_predictions_int)
# print(bas)

# f1 = f1_score(test_y_age, apparent_predictions_int, average='micro')
# print(f1)

# recall_score = recall_score(test_y_age, apparent_predictions_int, average='micro')
# print(recall_score)

# log_loss = log_loss(test_y_age, apparent_predictions_int)
# print(log_loss)

# accuracy_score = accuracy_score(test_y_age, apparent_predictions_int)
# print(accuracy_score)

# confusion_matrix = confusion_matrix(test_y_age, apparent_predictions_int)
# print(confusion_matrix)

# mean_absolute_error = mean_absolute_error(test_y_age, apparent_predictions_int)
# print(mean_absolute_error)
###
###
def checker(y_true, y_pred):
  print(metrics.explained_variance_score(y_true, y_pred), 'explained_variance_score' )
  print(metrics.max_error(y_true, y_pred), 'max_error')
  # max_error metric calculates the maximum residual error.
  print(metrics.mean_absolute_error(y_true, y_pred), 'mean_absolute_error')
  # Mean absolute error regression loss.
  print(metrics.mean_squared_error(y_true, y_pred), 'mean_squared_error')
  # Mean squared error regression loss.
  print(metrics.mean_squared_log_error(y_true, y_pred), 'mean_squared_log_error')
  # Mean squared logarithmic error regression loss.
  print(metrics.median_absolute_error(y_true, y_pred), 'median_absolute_error')
  # Median absolute error regression loss.
  # metrics.mean_absolute_percentage_error(y_true, y_pred)
  # Mean absolute percentage error regression loss.
  print(metrics.r2_score(y_true, y_pred), 'r2_score')
  # (coefficient of determination) regression score function.
  print(metrics.mean_poisson_deviance(y_true, y_pred), 'mean_poisson_deviance')
  # Mean Poisson deviance regression loss.
  print(metrics.mean_gamma_deviance(y_true, y_pred), 'mean_gamma_deviance')
  # Mean Gamma deviance regression loss.
  print(metrics.mean_tweedie_deviance(y_true, y_pred), 'mean_tweedie_deviance')
  # Mean Tweedie deviance regression loss.

checker(test_y_age, apparent_predictions_int)
# Out:
# 0.5635714844009176 explained_variance_score
# 42 max_error
# 11.242063492063492 mean_absolute_error
# 194.1058201058201 mean_squared_error
# 0.19241520611786952 mean_squared_log_error
# 10.0 median_absolute_error
# 0.5617339969411422 r2_score
# 5.269698431598892 mean_poisson_deviance
# 0.16706642183961398 mean_gamma_deviance
# 194.1058201058201 mean_tweedie_deviance

# %% [markdown]
# ---

# %% [markdown]
# ##**5.5 Performance Visualization**
#
# Let's create data visualizations to compare the predicted ages with the actual ages. We will create a few to survey which data visualization is the most useful for analysis.

# %%
# plot a scatterplot with a 'perfect prediction' line
sns.set_theme(style="darkgrid")
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(test_y_age, apparent_predictions)
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=3)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Observation:** Above, we can see the 'perfect prediction' dotted line and get a general sense of the error pattern in the system. Generally, there is a positive correlation between actual age and predicted age. We can also see some predictions far from the ideal line.

# %%
# jointplot - scatterplot with histogram
sns.jointplot(test_y_age, apparent_predictions)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Correlation**
#
# Check Pearson Correlation Coefficient between predicted ages and actual ages.

# %%
# corr(test_y_age, apparent_predictions)
np.corrcoef(test_y_age, apparent_predictions)
# Out:
# array([[1.        , 0.78868321],
#        [0.78868321, 1.        ]])

# %%
from sklearn.metrics import classification_report
classy_report = classification_report(test_y_age, apparent_predictions_int)
print(classy_report)
# Out:
#               precision    recall  f1-score   support
#
#            8       0.00      0.00      0.00        20
#            9       0.00      0.00      0.00        21
#           10       0.00      0.00      0.00        20
#           11       0.00      0.00      0.00        21
#           12       0.00      0.00      0.00        21
#           13       0.00      0.00      0.00        21
#           14       0.00      0.00      0.00        21
#           15       0.00      0.00      0.00        20
#           16       0.00      0.00      0.00        21
#           17       0.00      0.00      0.00        20
#           18       0.00      0.00      0.00        21
#           19       0.00      0.00      0.00        21
#           20       0.00      0.00      0.00        21
#           21       0.00      0.00      0.00        21
#           22       0.00      0.00      0.00        21
#           23       0.00      0.00      0.00        20
#           24       0.00      0.00      0.00        21
#           25       0.00      0.00      0.00        20
#           26       0.00      0.00      0.00        21
#           27       0.00      0.00      0.00        21
#           28       0.00      0.00      0.00        21
#           29       0.00      0.00      0.00        21
#           30       0.00      0.00      0.00        20
#           31       0.00      0.00      0.00        21
#           32       0.00      0.00      0.00        21
#           33       0.00      0.00      0.00        21
#           34       0.05      0.10      0.06        21
#           35       0.00      0.00      0.00        20
#           36       0.05      0.14      0.07        21
#           37       0.02      0.05      0.03        21
#           38       0.04      0.10      0.05        21
#           39       0.02      0.05      0.02        21
#           40       0.04      0.14      0.06        21
#           41       0.03      0.10      0.04        20
#           42       0.03      0.10      0.04        21
#           43       0.02      0.05      0.03        21
#           44       0.00      0.00      0.00        21
#           45       0.00      0.00      0.00        21
#           46       0.02      0.05      0.03        20
#           47       0.07      0.15      0.10        20
#           48       0.03      0.05      0.03        21
#           49       0.00      0.00      0.00        20
#           50       0.00      0.00      0.00        21
#           51       0.03      0.05      0.04        21
#           52       0.03      0.05      0.04        20
#           53       0.00      0.00      0.00        21
#           54       0.04      0.05      0.04        21
#           55       0.04      0.05      0.05        21
#           56       0.00      0.00      0.00        21
#           57       0.00      0.00      0.00        21
#           58       0.00      0.00      0.00        20
#           59       0.04      0.05      0.04        21
#           60       0.00      0.00      0.00        21
#           61       0.00      0.00      0.00        21
#           62       0.08      0.05      0.06        20
#           63       0.08      0.05      0.06        21
#           64       0.00      0.00      0.00        21
#           65       0.00      0.00      0.00        21
#           66       0.11      0.05      0.07        21
#           67       0.06      0.05      0.05        21
#           68       0.00      0.00      0.00        20
#           69       0.00      0.00      0.00        21
#           70       0.00      0.00      0.00        20
#           71       0.12      0.10      0.11        20
#           72       0.00      0.00      0.00        21
#           73       0.00      0.00      0.00        21
#           74       0.00      0.00      0.00        21
#           75       0.00      0.00      0.00        20
#           76       0.25      0.05      0.08        20
#           77       0.00      0.00      0.00        21
#           78       1.00      0.05      0.09        21
#           79       0.00      0.00      0.00        21
#           80       0.00      0.00      0.00        20
#
#     accuracy                           0.02      1512
#    macro avg       0.03      0.02      0.02      1512
# weighted avg       0.03      0.02      0.02      1512
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Confusion Matrix**
#
# We will create and plot a Confusion Matrix to visualize prediction accuracy in a grid.

# %%
# confusion_matrix
from sklearn.metrics import confusion_matrix
import itertools
sns.set_theme(style='dark')
# prediction_list = np.array(prediction_list) + 8
conf_mat1 = confusion_matrix(test_y_age, prediction_list)

# %%
# plot the confusion matrix 
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', export_as='confusion_matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, cmap=cmap, interpolation='nearest')
    plt.title(title, fontsize=22)
    plt.colorbar()
    a_list = list(range(73))
    b_list = [8,'',10,'','','','',15,'','','','',20,'','','','',25,'','','','',30,'','','','',35,'','','','',40,'','','','',\
                   45,'','','','',50,'','','','',55,'','','','',60,'','','','',65,'','','','',70,'','','','',75 ,'','','','',80]
    plt.xticks(a_list, b_list, fontsize=12)
    plt.yticks(a_list, b_list, fontsize=12)

    plt.tight_layout()
    plt.ylabel('Predicted Age', fontsize=18)
    plt.xlabel('Actual Age', fontsize=18)
    plt.savefig('/content/drive/MyDrive/YOUNGER/conf_mat1.png');

# %%
plt.figure(figsize=(10,10))
plot_confusion_matrix(conf_mat1, list(range(73)), normalize=False,
                      title="Confusion Matrix: Age Prediction, CNN Model 1")
plt.show()

# %% [markdown]
# **Observation:**
# Again, we can see the correlation trend forming a linear shape. Perfect predictions would form a dark blue line from top-left to bottom-right. The predictions are far from perfect.

# %% [markdown]
# ---

# %% [markdown]
# ##**5.6 Unseen Data Test**
#
# We will create a sequence to predict the ages of new images loaded through Google Drive and also images from on the Internet.
#
# We can imagine this being the "app" where a user inputs their photo and the app returns an age prediction. This is the practical application of the predictor.

# %%
# image preprocessing
def loadImage(filepath):
    test_img = image.load_img(filepath, target_size=(224, 224))
    test_img = image.img_to_array(test_img)
    test_img = np.expand_dims(test_img, axis = 0)
    test_img /= 255
    return test_img

# %%
# predictor function using the model created above
from keras.preprocessing import image
sns.set_theme(style='dark')

def image_age(photo):
  prediction = age_model.predict(loadImage(photo))
  img = image.load_img(photo)#, target_size=(224, 224))
  plt.xticks([], []), ax.set_xticks([]), plt.yticks([], []), ax.set_yticks([]) # clear x & y ticks
  plt.imshow(img)   # display image
  plt.show()
  
  # print("Predicted Age: ", (np.argmax(prediction))+8)
  apparent_age = np.round(np.sum(prediction * output_indexes, axis = 1))
  print(" Predicted Age: ", int(apparent_age[0]))

# %%
# visualize probabilites of each age class
def viz_prob(pic):
  prediction_1 = age_model.predict(loadImage(pic))
  y_pos = np.arange(73)+8
  plt.bar(y_pos, prediction_1[0], align='center', alpha=0.8)
  plt.ylabel('predicted probability')
  plt.xlabel('age')
  plt.title('Age Prediction Probabilities')
  plt.show()

# %% [markdown]
# **Load New Image, Predict Age, Visualize Probabilites**

# %%
# insert image from Google Drive by path
picture1 = "/content/drive/MyDrive/YOUNGER/face_old.jpeg"

image_age(picture1)
viz_prob(picture1)
# Out:
#  Predicted Age:  60

# %%
picture2 = "/content/drive/MyDrive/YOUNGER/prem_linked.jpg"
image_age(picture2)
print(' Actual Age:  35')
viz_prob(picture2)
# Out:
#  Predicted Age:  45
#  Actual Age:  35

# %%
# create a web image upload & predict sequence
from PIL import Image
import requests

def web_age(url):  
  web_photo = Image.open(requests.get(url, stream=True).raw).save("web_photo.jpg")
  picture1 = "/content/web_photo.jpg"
  image_age(picture1)
  # viz_prob(picture1)

# %%
url = 'https://i.guim.co.uk/img/media/68b70e0ccc658b9b01cc7bf6a972134f2a5136e4/0_186_1900_1139/master/1900.jpg?width=1200&height=1200&quality=85&auto=format&fit=crop&s=c391df10a394dc50fafe584915c753e5'
web_age(url)
# Out:
#  Predicted Age:  52

# %%
url = "https://media.allure.com/photos/5e8359941cb813000841fb8b/3:2/w_3000,h_2000,c_limit/celine%20dion.jpg"
web_age(url)
print(' Actual Age:  52')
# Out:
#  Predicted Age:  55
#  Actual Age:  52

# %%
url ="https://i.insider.com/5fca6611037cbd0018613df7?width=700"
web_age(url)
print(' Actual Age:  50')
# Out:
#  Predicted Age:  42
#  Actual Age:  50

# %%
url = 'https://assets.vogue.com/photos/5e6f950f5530ac0009b932fb/1:1/w_3538,h_3538,c_limit/GettyImages-1205201930.jpg'
web_age(url)
print(' Actual Age:  63')
# Out:
#  Predicted Age:  51
#  Actual Age:  63

# %%
url = 'https://static.wikia.nocookie.net/euphoria-hbo/images/5/5c/Zendaya.jpg/revision/latest?cb=20190601162350'
web_age(url)
print(' Actual Age:  20')
# Out:
#  Predicted Age:  38
#  Actual Age:  20

# %%
url = 'https://i.guim.co.uk/img/media/7f2b972fa41cd4d26a3620cea335aad33cde6c32/0_127_3500_2101/master/3500.jpg?width=445&quality=45&auto=format&fit=max&dpr=2&s=02571424bc9abc13340589ef47eb7b0b'
web_age(url)
print(' Actual Age:  34')
# Out:
#  Predicted Age:  40
#  Actual Age:  34

# %%
url = 'https://myimagejourney.com/wp-content/uploads/2013/08/2013-04-20-16.02.40.jpg'
web_age(url)
# Out:
#  Predicted Age:  29

# %%
url = 'https://static.wikia.nocookie.net/harrypotter/images/9/97/Harry_Potter.jpg/revision/latest?cb=20140603201724'
web_age(url)
print(' Actual Age:  20')
# Out:
#  Predicted Age:  39
#  Actual Age:  20

# %%
url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRed4B_N95FjRE0a-2sn3OEXAjc0SkMkWeJTQ&usqp=CAU'
web_age(url)
# Out:
#  Predicted Age:  47

# %% [markdown]
# ---

# %% [markdown]
# # **VI. SUMMARY**

# %% [markdown]
# Well, that was a lot. Let's take a look at what this notebook covers.
#
# **Preprocessing**
#
# During preprocessing, we loaded and prepared the data for machine learning by one-hot encoding the target classes. We scaled the pixel values from 0-255 to 0-1. We also split the data into training and testing subsets.
#
# **Modeling**
#
# Onward to modeling, we used a proven model arcitecture with pretrained weights for the first layers to expedite our learning. By using transfer learning we were able to use the existing model weights that have been previously trained on a massive 2.6 million image dataset. We froze the early layers and focuses on training the later layers in the model. Next we trained the model, observed results of the training, and reset the batchsize and the number of epochs to achieve a reasonable learning rate without overfitting.
#
# **Metrics**
#
# Our primary model performance metric is validation loss. We created our model to train to minimize validation loss and save the best weights progressively. We eventually got down to a reasonable validation loss for this project.
#
# Our primary overall metric is Mean Absolute Error (MAE). We want to minimize how far our predicted are from the actual ages. So far our MAE is still far from ideal. Training on a lot more data will help.
#
# **Visualizations**
#
# We created a confusion matrix, a scatterplot and a jointplot to get a sense of how well the model is predicting. Overall, the general trend is positive but there is room for improvement.
#
# **Unseen Data**
#
# We created a small program to predict the ages for new images from Google Drive and from the Internet. The results were encouraging.

# %% [markdown]
# ---

# %%
# one for the road
url = 'https://imagesvc.meredithcorp.io/v3/mm/image?q=85&c=sc&poi=face&w=1200&h=1600&url=https%3A%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F20%2F2019%2F05%2Fkim-beauty.jpg'
web_age(url)
print(' Actual Age:  37')
# Out:
#  Predicted Age:  37
#  Actual Age:  37

# %% [markdown]
# ---

# %% [markdown]
# # **VII. REFERENCES**

# %% [markdown]
# 1.   https://data.vision.ee.ethz.ch/cvl/rrothe/imdb-wiki/
# 2.   https://data.vision.ee.ethz.ch/cvl/publications/papers/proceedings/eth_biwi_01229.pdf
# 3. https://sefiks.com/2019/02/13/apparent-age-and-gender-prediction-in-keras/
# 4. https://www.researchgate.net/publication/265125544_Face_Detection_without_Bells_and_Whistles
# 5. https://github.com/yu4u/age-gender-estimation
# 6. https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf
# 7. https://link.springer.com/chapter/10.1007/978-3-319-10593-2_47
#
#
# ---

# %% [markdown]
# # **VIII. APPENDIX**

# %% [markdown]
# **Model Summary**
#
# [VGG-Face Model](https://https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf) was the basis for our model. We used the VGG-Face structure and trained on the last 4 custom layers.

# %%
age_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_input (InputL [(None, 224, 224, 3)]     0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 226, 226, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 226, 226, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 114, 114, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 114, 114, 128)     0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 58, 58, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# zero_padding2d_5 (ZeroPaddin (None, 58, 58, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# zero_padding2d_6 (ZeroPaddin (None, 58, 58, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# zero_padding2d_7 (ZeroPaddin (None, 30, 30, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 30, 30, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 30, 30, 512)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# zero_padding2d_10 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# zero_padding2d_11 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# zero_padding2d_12 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 1, 4096)        102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 1, 4096)        16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 4096)        0
# _________________________________________________________________
# predictions (Conv2D)         (None, 1, 1, 73)          299081
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 73)                0
# _________________________________________________________________
# activation_1 (Activation)    (None, 73)                0
# =================================================================
# Total params: 134,559,625
# Trainable params: 119,844,937
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ---

# %% [markdown]
# **TensorBoard**
# TensorBoard visualization for experimentation.

# %%
# # !kill 380
# %tensorboard --logdir logs/fit

# %%
# !tensorboard dev upload \
#   --logdir logs/fit \
#   --name "My latest experiment" \
#   --description "Simple comparison of hyperparameters" \
#   --one_shot

# %% [markdown]
# [TensorBoard for this Notebook](https://tensorboard.dev/experiment/WF9igsXfRIGeYsDu0caNzw/)

# %% [markdown]
# ---

# %% [markdown]
# Data Augmentation = FALSE
#
# Learning Rate = .0005
#
# Epochs = 200
