# %% [markdown]
# <a href="https://colab.research.google.com/github/premonish/YOUNGER_deprecated/blob/main/YOUNGER_Age_Estimator_PREPROCESS_MODEL_043021_1111.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **YOUNGER - Age Estimator**

# %% [markdown]
# # **IV. PREPROCESSING**

# %% [markdown]
# ## **4.1 Contents**
# * 4.1 Contents
# * 4.2 Introduction
# * 4.3 Imports
# * 4.4 Load Data
# * 4.5 Transform Data
# * 4.6 Train/Test Split
# * 4.7 Data Augmentation
# * 4.8 Transfer Learning
# * 4.9 Summary
# * 4.10 References
#
#
# ---

# %% [markdown]
# ##**4.2 Introduction**
#
# Previously, to create an age-predictor, we have completed a notebook import data and explore its attributes: [Data Wrangling & Exploratory Data Analysis](https://github.com/premonish/YOUNGER/blob/main/notebooks/YOUNGER_Age_Estimator_WRANGLING_EDA_v2.ipynb). We took a close look at the metadata and plotted some histograms of the variable distributions. We transformed the data to extract the age of the primary face in each image from their date-of-birth and the date the photo was taken. We focused on extracting a long array of vectors of the pixel information per photo. We finished the previous phase by creating 2 arrays: 'matrix_x' with each row containing the (150,000+ pixel/image) data from each image in the dataset, and 'vector_y' containing the corresponding 'age' labels for the images.
#
# In this notebook, we will focus on Preprocessing & Modeling. In particular, we will use a Convolutional Neural Network, which is industry standard for Machine Learning image classification tasks due to its unmatched performance.
#
#
# ---

# %% [markdown]
# **Historical Context**
# >
# > Image classification has been around for decades, however the field has been rapidly maturing in the last decade.  Since 2010, [ImageNet](https://https://en.wikipedia.org/wiki/ImageNet) Large Scale Visual Recognition Challenge (ILSVRC) is an annual competition where teams attempt to categorize thousands of images into 1,000 classes. In 2012, 'AlexNet' won the competition by a landslide and this is considered a pivotal moment in the history of deep learning, enabled by ingenious data scientists, a massive labeled dataset, and GPUs for training.

# %% [markdown]
# **PREPROCESSING** will be focused on three main sections.
#
# 1. Create Dummy Variables for categorical variables where appropriate.
# 2. Standardize the magnitude of numeric features using a scaler.
# 3. Split data into testing and training datasets.

# %% [markdown]
# **MODELING** will focus on the following four phases.
# 1. Train the models on the dataset (fit)
# 2. Review model performance metrics
# 3. Iterate over other models
# 4. Identify the final model
#
#
# ---

# %% [markdown]
# ## **4.3 Imports**

# %%
# !pip install tensorflow

# %%
# Create a list of currently installed python libraries for posterity
# !pip freeze > requirements.txt

# %%
### IMPORT libraries and packages ###
### I get by with a little help from my friends ###
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# deep-learning imports

from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.layers import Dense, Activation, Dropout, Flatten, Input, Convolution2D, ZeroPadding2D, MaxPooling2D, Activation
from keras.layers import Conv2D, AveragePooling2D
from keras.models import Model, Sequential
from keras import metrics
from keras.models import model_from_json

# import os
# import PIL
# from PIL import Image
# import seaborn as sns
# from pathlib import Path
# import random
# import requests
# import scipy.io
# from keras.preprocessing import image
# from keras.applications.resnet import preprocess_input
# from datetime import datetime, date, time, timedelta

# %%
# mount GDrive where the dataset is stored for Colab environment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **4.4 Load Data**
# Let's load the compressed numpy arrays from disk, extract data, and check the number of rows in our dataset.

# %%
# %%time
from numpy import asarray, savez_compressed, load
# load dict of arrays
images = np.load('/content/drive/MyDrive/YOUNGER/data2.npz', allow_pickle=True)
matrix_x = images.f.arr_0
matrix_x.shape
# Out:
# CPU times: user 1min, sys: 8.76 s, total: 1min 9s
# Wall time: 1min 11s

# %%
# load the ages array 'vector_y'
ages = np.load('/content/drive/MyDrive/YOUNGER/vector_y.npz', allow_pickle=True)
vector_y = ages.f.arr_0
vector_y.shape
# Out:
# (22138,)

# %%
# check output matrix_x & vector_y shapes
# both matrix_x and vector_y are arrays of the same length 
assert vector_y.shape == matrix_x.shape

# %%
# subset data
X0 = matrix_x[:5000]
# X1 = matrix_x[5000:6000]
# X2 = matrix_x[10000:12000]
# X3 = matrix_x[15000:20000]
# X4 = matrix_x[20000:]

X = matrix_x[:5000]
y = vector_y[:5000]

### NOTE: I'm running some tests to see how many images to include without overwhelming Google Colab's Ram. 
### I have already upgraded to Colab Pro for this project and have been reaching the RAM limits

# y = vector_y[:6000]
# convert to tensor
# [tf.convert_to_tensor(a) for a in X]
# [tf.convert_to_tensor(a) for a in y];

# %%
plt.hist(y)
# Out:
# (array([  12.,  219., 1629., 1072.,  756.,  627.,  338.,  231.,   91.,
#           25.]),
#  array([ 1. , 10.4, 19.8, 29.2, 38.6, 48. , 57.4, 66.8, 76.2, 85.6, 95. ]),
#  <a list of 10 Patch objects>)

# %%
#SHOW DISTRIBUTION OF THE CLASSES AS PERCENTAGE#

# %% [markdown]
# ## **4.5 Transform Data**

# %% [markdown]
# **One-Hot Encoding**
#
# We need to encode the 'ages' label as categorical (binary) representations to prevent a hierarchical interpretation.
# The Keras API provides a 'to_categorical()' method that can be used to one-hot encode integer data.

# %%
classes = 101 # ages 0 to 100
target = y
target_classes = keras.utils.to_categorical(target, classes) # "Converts a class vector (integers) to binary class matrix."

# %% [markdown]
# **Reshaping the Data**
#
# We must reshape the data into the standard input array shape of a 'rank 4 tensor' to prepare for the Tensorflow CNN.
#
# (b, w, h, c) : (batch, width, height, channels)

# %%
features = []
for i in range(0, len(X)):
    features.append(X0[i])
features = np.array(features)
features = features.reshape(len(X),224,224,3)
features.shape
# Out:
# (5000, 224, 224, 3)

# %%
#### TEST ###$#$#$
### NOTE: I'm running some tests to see how many images to include without overwhelming Google Colab's Ram. 
### I have already upgraded to Colab Pro for this project and have been reaching the RAM limits
# %%time
# features = []
# # for i in range(0, len(X0)):
# #     features.append(X0[i])
# # for i in range(0, len(X1)):
# #     features.append(X1[i])
# # for i in range(0, len(X2)):
# #     features.append(X2[i])
# # for i in range(0, len(X3)):
# #     features.append(X3[i])
# features = np.array(features)

# %% [markdown]
# **Scale the Data**
#
# Each of the pixel values range from 0-255. Let's scale the values to from 0-1 by dividing each value by 255. Interestingly, we are actually performing this operation virtually instantly 150,528 times per image (times the number of images).

# %%
features /= 255        # scale down pixel values to range [0, 1]
print("The maximum value in our dataset is:", features.max())
# Out:
# The maximum value in our dataset is: 1.0

# %% [markdown]
# ## **4.6 Train/Test Split**
# We will divide the dataset randomly into training data and test data (80/20). We will later perform data augmentation on only the training set to help balance the classes of ages in the dataset.

# %%
# train/ test split
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(features, target_classes, test_size=0.20, random_state=42)
                                                    # , stratify=target_classes)

# %%
# print("X_train shape =",X_train.shape,"| X_test shape =",X_test.shape)
# print("y_train shape =",y_train.shape,"| y_test shape =",y_test.shape)

print("X_train shape =",train_x.shape,"| X_test shape =",test_x.shape)
print("y_train shape =",train_y.shape,"| y_test shape =",test_y.shape)
# Out:
# X_train shape = (4000, 224, 224, 3) | X_test shape = (1000, 224, 224, 3)
# y_train shape = (4000, 101) | y_test shape = (1000, 101)

# %% [markdown]
# ## **4.7 Data Augmentation**
# Balance the classes by upsampling the underrepresented classes. ImageDataGenerator creates transformed images to expand the training segment of the dataset.

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#         featurewise_center=False,  # set input mean to 0 over the dataset
#         samplewise_center=False,  # set each sample mean to 0
#         featurewise_std_normalization=False,  # divide inputs by std of the dataset
#         samplewise_std_normalization=False,  # divide each input by its std
#         zca_whitening=False,  # apply ZCA whitening
#         rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
#         zoom_range = 0.2, # Randomly zoom image 
#         width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#         height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
#         horizontal_flip = True,  # randomly flip images
#         vertical_flip=False)  # randomly flip images

# train_x = datagen.fit(train_x);

# %%
# bgen = BalancedDataGenerator(features, target, datagen, batch_size=32)

# %%
# steps_per_epoch = bgen.steps_per_epoch

# %% [markdown]
# ## **4.8 CNN Architecture**
#
# I'll start by testing an established effective architecture (VGG-Face model) for this task along with trained weights. ***[UPDATE REQUIRED: INCLUDE CITATION & DETAILS]***.
# https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf

# %%
#VGG-Face model
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(224,224, 3)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(Convolution2D(4096, (7, 7), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(4096, (1, 1), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(2622, (1, 1)))
model.add(Flatten())
model.add(Activation('softmax'))

# %% [markdown]
# ## **4.9 Transfer Learning**
#
# Load trained weights. ***[UPDATE REQUIRED: INCLUDE CITATION & DETAILS]***.
# https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf

# %%
model.load_weights('/content/drive/MyDrive/YOUNGER/vgg_face_weights.h5')

# %%
# freeze layers to use transfer learning effectively
for layer in model.layers[:-7]:
  layer.trainable = False
 
base_model_output = Sequential()
base_model_output = Convolution2D(101, (1, 1), name='predictions')(model.layers[-4].output)
base_model_output = Flatten()(base_model_output)
base_model_output = Activation('softmax')(base_model_output)
 
age_model = Model(inputs=model.input, outputs=base_model_output)

# %%
#check trainable layers
if False:
    for layer in model.layers:
        print(layer, layer.trainable)
    
    print("------------------------")
    for layer in age_model.layers:
        print(layer, layer.trainable)

# %%
# Stochastic Gradient Descent = sgd
# compile the model
sgd = keras.optimizers.SGD(lr=1e-6, decay=1e-6, momentum=.8, nesterov=True)

age_model.compile(loss='categorical_crossentropy'
                  , optimizer=keras.optimizers.Adam()
                  #, optimizer = sgd
                  , metrics=['accuracy']
                 )

# %%
# create checkpoint which saves the best model based on loss on the validation data
checkpointer = ModelCheckpoint(
    filepath='/content/classification_age_model.hdf5'
    , monitor = "val_loss"
    # , monitor = "val_accuracy"
    , verbose=1
    , save_best_only=True
    , mode = 'auto'
)

# %%
# set batch size and # of epochs
# fit the model on training set & validate on the test set
enableFit = True
scores = []

if enableFit:
    # epochs = 250 # original
    batch_size = 256 # original
    epochs = 100
    # batch_size = 32

    for i in range(epochs):
        print("epoch ",i)
        
        ix_train = np.random.choice(train_x.shape[0], size=batch_size)
        
        score = age_model.fit(
            train_x[ix_train], train_y[ix_train]
            , epochs=1
            , validation_data=(test_x, test_y)
            , callbacks=[checkpointer]
        )
        
        scores.append(score)
    
    #restore the best weights
    from keras.models import load_model
    age_model = load_model('/content/classification_age_model.hdf5')
    
    age_model.save_weights('/content/drive/MyDrive/YOUNGER/age_model_weights.h5')
        
else:
    #pre-trained weights for age prediction: https://drive.google.com/file/d/1YCox_4kJ-BYeXq27uUbasu--yz28zUMV/view?usp=sharing
    age_model.load_weights("/content/drive/MyDrive/YOUNGER/age_model_weights.h5")
# Out:
# epoch  0
# 8/8 [==============================] - 27s 802ms/step - loss: 4.5495 - accuracy: 0.0411 - val_loss: 4.2929 - val_accuracy: 0.0370
#
# Epoch 00001: val_loss improved from inf to 4.29291, saving model to /content/classification_age_model.hdf5
# epoch  1
# 8/8 [==============================] - 4s 588ms/step - loss: 4.1256 - accuracy: 0.0312 - val_loss: 4.0952 - val_accuracy: 0.0220
#
# Epoch 00001: val_loss improved from 4.29291 to 4.09516, saving model to /content/classification_age_model.hdf5
# epoch  2
# 8/8 [==============================] - 4s 587ms/step - loss: 4.0167 - accuracy: 0.0547 - val_loss: 4.0549 - val_accuracy: 0.0310
#
# Epoch 00001: val_loss improved from 4.09516 to 4.05486, saving model to /content/classification_age_model.hdf5
# epoch  3
# 8/8 [==============================] - 4s 587ms/step - loss: 4.0941 - accuracy: 0.0312 - val_loss: 3.9727 - val_accuracy: 0.0380
#
# Epoch 00001: val_loss improved from 4.05486 to 3.97270, saving model to /content/classification_age_model.hdf5
# epoch  4
# 8/8 [==============================] - 4s 587ms/step - loss: 3.9088 - accuracy: 0.0195 - val_loss: 3.9584 - val_accuracy: 0.0380
#
# Epoch 00001: val_loss improved from 3.97270 to 3.95837, saving model to /content/classification_age_model.hdf5
# epoch  5
# 8/8 [==============================] - 4s 587ms/step - loss: 3.9595 - accuracy: 0.0508 - val_loss: 3.9159 - val_accuracy: 0.0360
#
# Epoch 00001: val_loss improved from 3.95837 to 3.91586, saving model to /content/classification_age_model.hdf5
# epoch  6
# 8/8 [==============================] - 4s 593ms/step - loss: 3.7728 - accuracy: 0.0703 - val_loss: 3.8509 - val_accuracy: 0.0510
#
# Epoch 00001: val_loss improved from 3.91586 to 3.85094, saving model to /content/classification_age_model.hdf5
# epoch  7
# 8/8 [==============================] - 4s 586ms/step - loss: 3.8198 - accuracy: 0.0625 - val_loss: 3.8573 - val_accuracy: 0.0360
#
# Epoch 00001: val_loss did not improve from 3.85094
# epoch  8
# 8/8 [==============================] - 4s 586ms/step - loss: 3.7726 - accuracy: 0.0703 - val_loss: 3.8163 - val_accuracy: 0.0500
#
# Epoch 00001: val_loss improved from 3.85094 to 3.81625, saving model to /content/classification_age_model.hdf5
# epoch  9
# 8/8 [==============================] - 4s 586ms/step - loss: 3.7406 - accuracy: 0.0742 - val_loss: 3.7796 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss improved from 3.81625 to 3.77962, saving model to /content/classification_age_model.hdf5
# epoch  10
# 8/8 [==============================] - 4s 586ms/step - loss: 3.6766 - accuracy: 0.0742 - val_loss: 3.8370 - val_accuracy: 0.0510
#
# Epoch 00001: val_loss did not improve from 3.77962
# epoch  11
# 8/8 [==============================] - 4s 587ms/step - loss: 3.7168 - accuracy: 0.0703 - val_loss: 3.7932 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss did not improve from 3.77962
# epoch  12
# 8/8 [==============================] - 4s 589ms/step - loss: 3.6580 - accuracy: 0.0703 - val_loss: 3.7893 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss did not improve from 3.77962
# epoch  13
# 8/8 [==============================] - 4s 586ms/step - loss: 3.5946 - accuracy: 0.0742 - val_loss: 3.7961 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss did not improve from 3.77962
# epoch  14
# 8/8 [==============================] - 4s 586ms/step - loss: 3.6015 - accuracy: 0.0938 - val_loss: 3.7413 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss improved from 3.77962 to 3.74132, saving model to /content/classification_age_model.hdf5
# epoch  15
# 8/8 [==============================] - 4s 588ms/step - loss: 3.5518 - accuracy: 0.0625 - val_loss: 3.7393 - val_accuracy: 0.0410
#
# Epoch 00001: val_loss improved from 3.74132 to 3.73932, saving model to /content/classification_age_model.hdf5
# epoch  16
# 8/8 [==============================] - 4s 590ms/step - loss: 3.5826 - accuracy: 0.1367 - val_loss: 3.7145 - val_accuracy: 0.0480
#
# Epoch 00001: val_loss improved from 3.73932 to 3.71452, saving model to /content/classification_age_model.hdf5
# epoch  17
# 8/8 [==============================] - 4s 587ms/step - loss: 3.4604 - accuracy: 0.1367 - val_loss: 3.7100 - val_accuracy: 0.0550
#
# Epoch 00001: val_loss improved from 3.71452 to 3.70996, saving model to /content/classification_age_model.hdf5
# epoch  18
# 8/8 [==============================] - 4s 588ms/step - loss: 3.4878 - accuracy: 0.1211 - val_loss: 3.7879 - val_accuracy: 0.0480
#
# Epoch 00001: val_loss did not improve from 3.70996
# epoch  19
# 8/8 [==============================] - 4s 588ms/step - loss: 3.4777 - accuracy: 0.1250 - val_loss: 3.6872 - val_accuracy: 0.0440
#
# Epoch 00001: val_loss improved from 3.70996 to 3.68723, saving model to /content/classification_age_model.hdf5
# epoch  20
# 8/8 [==============================] - 4s 587ms/step - loss: 3.5936 - accuracy: 0.1328 - val_loss: 3.7181 - val_accuracy: 0.0500
#
# Epoch 00001: val_loss did not improve from 3.68723
# epoch  21
# 8/8 [==============================] - 4s 588ms/step - loss: 3.3264 - accuracy: 0.1250 - val_loss: 3.7110 - val_accuracy: 0.0390
#
# Epoch 00001: val_loss did not improve from 3.68723
# epoch  22
# 8/8 [==============================] - 4s 587ms/step - loss: 3.4047 - accuracy: 0.1211 - val_loss: 3.6874 - val_accuracy: 0.0290
#
# Epoch 00001: val_loss did not improve from 3.68723
# epoch  23
# 8/8 [==============================] - 4s 588ms/step - loss: 3.2884 - accuracy: 0.1211 - val_loss: 3.6961 - val_accuracy: 0.0440
#
# Epoch 00001: val_loss did not improve from 3.68723
# epoch  24
# 8/8 [==============================] - 4s 586ms/step - loss: 3.3419 - accuracy: 0.1562 - val_loss: 3.7145 - val_accuracy: 0.0490
#
# Epoch 00001: val_loss did not improve from 3.68723
# epoch  25
# 8/8 [==============================] - 4s 589ms/step - loss: 3.4046 - accuracy: 0.1680 - val_loss: 3.7189 - val_accuracy: 0.0460
#
# Epoch 00001: val_loss did not improve from 3.68723
# epoch  26
# 8/8 [==============================] - 4s 588ms/step - loss: 3.2682 - accuracy: 0.1445 - val_loss: 3.6704 - val_accuracy: 0.0600
#
# Epoch 00001: val_loss improved from 3.68723 to 3.67040, saving model to /content/classification_age_model.hdf5
# epoch  27
# 8/8 [==============================] - 4s 589ms/step - loss: 3.2001 - accuracy: 0.1484 - val_loss: 3.6524 - val_accuracy: 0.0500
#
# Epoch 00001: val_loss improved from 3.67040 to 3.65238, saving model to /content/classification_age_model.hdf5
# epoch  28
# 8/8 [==============================] - 4s 586ms/step - loss: 3.2633 - accuracy: 0.1484 - val_loss: 3.7412 - val_accuracy: 0.0520
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  29
# 8/8 [==============================] - 4s 587ms/step - loss: 3.1049 - accuracy: 0.2188 - val_loss: 3.7082 - val_accuracy: 0.0370
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  30
# 8/8 [==============================] - 4s 590ms/step - loss: 3.1715 - accuracy: 0.1758 - val_loss: 3.7394 - val_accuracy: 0.0590
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  31
# 8/8 [==============================] - 4s 587ms/step - loss: 3.2411 - accuracy: 0.1875 - val_loss: 3.6893 - val_accuracy: 0.0440
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  32
# 8/8 [==============================] - 4s 615ms/step - loss: 3.1611 - accuracy: 0.1758 - val_loss: 3.6938 - val_accuracy: 0.0500
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  33
# 8/8 [==============================] - 4s 607ms/step - loss: 3.1102 - accuracy: 0.1992 - val_loss: 3.7230 - val_accuracy: 0.0500
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  34
# 8/8 [==============================] - 4s 593ms/step - loss: 2.9647 - accuracy: 0.2305 - val_loss: 3.7505 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  35
# 8/8 [==============================] - 4s 589ms/step - loss: 2.9415 - accuracy: 0.2148 - val_loss: 3.7121 - val_accuracy: 0.0490
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  36
# 8/8 [==============================] - 4s 608ms/step - loss: 2.8578 - accuracy: 0.2656 - val_loss: 3.6972 - val_accuracy: 0.0440
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  37
# 8/8 [==============================] - 4s 607ms/step - loss: 3.0206 - accuracy: 0.2344 - val_loss: 3.7606 - val_accuracy: 0.0400
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  38
# 8/8 [==============================] - 4s 593ms/step - loss: 3.0737 - accuracy: 0.2109 - val_loss: 3.6688 - val_accuracy: 0.0440
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  39
# 8/8 [==============================] - 4s 587ms/step - loss: 2.9057 - accuracy: 0.2773 - val_loss: 3.6828 - val_accuracy: 0.0460
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  40
# 8/8 [==============================] - 4s 589ms/step - loss: 2.8663 - accuracy: 0.2305 - val_loss: 3.6946 - val_accuracy: 0.0560
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  41
# 8/8 [==============================] - 4s 608ms/step - loss: 2.9473 - accuracy: 0.2461 - val_loss: 3.7865 - val_accuracy: 0.0370
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  42
# 8/8 [==============================] - 4s 591ms/step - loss: 2.8410 - accuracy: 0.2578 - val_loss: 3.7223 - val_accuracy: 0.0410
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  43
# 8/8 [==============================] - 4s 587ms/step - loss: 2.8580 - accuracy: 0.2656 - val_loss: 3.7374 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  44
# 8/8 [==============================] - 4s 588ms/step - loss: 2.5274 - accuracy: 0.3281 - val_loss: 3.7988 - val_accuracy: 0.0490
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  45
# 8/8 [==============================] - 4s 609ms/step - loss: 2.7129 - accuracy: 0.2734 - val_loss: 3.8102 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  46
# 8/8 [==============================] - 4s 593ms/step - loss: 2.7983 - accuracy: 0.2852 - val_loss: 3.7491 - val_accuracy: 0.0510
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  47
# 8/8 [==============================] - 4s 588ms/step - loss: 2.6762 - accuracy: 0.3086 - val_loss: 3.8365 - val_accuracy: 0.0400
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  48
# 8/8 [==============================] - 4s 588ms/step - loss: 2.7264 - accuracy: 0.2734 - val_loss: 3.8161 - val_accuracy: 0.0420
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  49
# 8/8 [==============================] - 4s 605ms/step - loss: 2.5916 - accuracy: 0.3164 - val_loss: 3.7756 - val_accuracy: 0.0480
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  50
# 8/8 [==============================] - 4s 595ms/step - loss: 2.6385 - accuracy: 0.3125 - val_loss: 3.7942 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  51
# 8/8 [==============================] - 4s 587ms/step - loss: 2.6121 - accuracy: 0.3242 - val_loss: 3.8998 - val_accuracy: 0.0380
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  52
# 8/8 [==============================] - 4s 587ms/step - loss: 2.4679 - accuracy: 0.3438 - val_loss: 3.7890 - val_accuracy: 0.0510
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  53
# 8/8 [==============================] - 4s 605ms/step - loss: 2.5056 - accuracy: 0.3594 - val_loss: 3.8313 - val_accuracy: 0.0440
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  54
# 8/8 [==============================] - 4s 590ms/step - loss: 2.4855 - accuracy: 0.4102 - val_loss: 3.7474 - val_accuracy: 0.0510
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  55
# 8/8 [==============================] - 4s 588ms/step - loss: 2.4815 - accuracy: 0.3828 - val_loss: 3.7527 - val_accuracy: 0.0500
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  56
# 8/8 [==============================] - 4s 587ms/step - loss: 2.3517 - accuracy: 0.3711 - val_loss: 3.8599 - val_accuracy: 0.0510
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  57
# 8/8 [==============================] - 4s 604ms/step - loss: 2.5808 - accuracy: 0.3633 - val_loss: 3.8024 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  58
# 8/8 [==============================] - 4s 591ms/step - loss: 2.3221 - accuracy: 0.4219 - val_loss: 3.8164 - val_accuracy: 0.0370
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  59
# 8/8 [==============================] - 4s 587ms/step - loss: 2.4009 - accuracy: 0.4023 - val_loss: 3.7986 - val_accuracy: 0.0460
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  60
# 8/8 [==============================] - 4s 587ms/step - loss: 2.1204 - accuracy: 0.4531 - val_loss: 3.7878 - val_accuracy: 0.0480
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  61
# 8/8 [==============================] - 4s 598ms/step - loss: 2.2109 - accuracy: 0.4258 - val_loss: 3.7993 - val_accuracy: 0.0580
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  62
# 8/8 [==============================] - 4s 591ms/step - loss: 2.1328 - accuracy: 0.4453 - val_loss: 3.8357 - val_accuracy: 0.0680
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  63
# 8/8 [==============================] - 4s 585ms/step - loss: 2.3242 - accuracy: 0.4023 - val_loss: 3.8443 - val_accuracy: 0.0500
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  64
# 8/8 [==============================] - 4s 588ms/step - loss: 2.3616 - accuracy: 0.3594 - val_loss: 3.9367 - val_accuracy: 0.0420
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  65
# 8/8 [==============================] - 4s 601ms/step - loss: 2.2362 - accuracy: 0.4258 - val_loss: 3.8778 - val_accuracy: 0.0490
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  66
# 8/8 [==============================] - 4s 593ms/step - loss: 2.2932 - accuracy: 0.3906 - val_loss: 3.8481 - val_accuracy: 0.0490
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  67
# 8/8 [==============================] - 4s 587ms/step - loss: 2.0969 - accuracy: 0.4414 - val_loss: 3.8401 - val_accuracy: 0.0500
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  68
# 8/8 [==============================] - 4s 588ms/step - loss: 1.9913 - accuracy: 0.4805 - val_loss: 3.8565 - val_accuracy: 0.0480
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  69
# 8/8 [==============================] - 4s 598ms/step - loss: 2.1290 - accuracy: 0.4570 - val_loss: 3.9027 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  70
# 8/8 [==============================] - 4s 593ms/step - loss: 2.0085 - accuracy: 0.5078 - val_loss: 3.8798 - val_accuracy: 0.0480
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  71
# 8/8 [==============================] - 4s 590ms/step - loss: 2.0012 - accuracy: 0.4766 - val_loss: 3.8878 - val_accuracy: 0.0460
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  72
# 8/8 [==============================] - 4s 586ms/step - loss: 2.1555 - accuracy: 0.4609 - val_loss: 3.9409 - val_accuracy: 0.0480
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  73
# 8/8 [==============================] - 4s 595ms/step - loss: 2.3380 - accuracy: 0.4219 - val_loss: 3.8892 - val_accuracy: 0.0550
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  74
# 8/8 [==============================] - 4s 590ms/step - loss: 1.8313 - accuracy: 0.5000 - val_loss: 3.8978 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  75
# 8/8 [==============================] - 4s 587ms/step - loss: 2.1476 - accuracy: 0.4688 - val_loss: 3.8330 - val_accuracy: 0.0440
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  76
# 8/8 [==============================] - 4s 587ms/step - loss: 1.7606 - accuracy: 0.5469 - val_loss: 3.8594 - val_accuracy: 0.0530
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  77
# 8/8 [==============================] - 4s 594ms/step - loss: 1.9399 - accuracy: 0.4844 - val_loss: 3.8719 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  78
# 8/8 [==============================] - 4s 589ms/step - loss: 1.8389 - accuracy: 0.5391 - val_loss: 3.9220 - val_accuracy: 0.0370
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  79
# 8/8 [==============================] - 4s 587ms/step - loss: 1.8576 - accuracy: 0.4844 - val_loss: 3.8754 - val_accuracy: 0.0410
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  80
# 8/8 [==============================] - 4s 587ms/step - loss: 1.7402 - accuracy: 0.5625 - val_loss: 3.9950 - val_accuracy: 0.0410
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  81
# 8/8 [==============================] - 4s 595ms/step - loss: 1.8277 - accuracy: 0.5391 - val_loss: 3.9706 - val_accuracy: 0.0380
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  82
# 8/8 [==============================] - 4s 590ms/step - loss: 1.5518 - accuracy: 0.5781 - val_loss: 4.0391 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  83
# 8/8 [==============================] - 4s 586ms/step - loss: 1.7060 - accuracy: 0.5625 - val_loss: 3.9396 - val_accuracy: 0.0480
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  84
# 8/8 [==============================] - 4s 588ms/step - loss: 1.6374 - accuracy: 0.5742 - val_loss: 3.9883 - val_accuracy: 0.0500
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  85
# 8/8 [==============================] - 4s 593ms/step - loss: 1.8421 - accuracy: 0.5273 - val_loss: 3.9658 - val_accuracy: 0.0490
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  86
# 8/8 [==============================] - 4s 589ms/step - loss: 1.7611 - accuracy: 0.5547 - val_loss: 3.9457 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  87
# 8/8 [==============================] - 4s 588ms/step - loss: 1.6014 - accuracy: 0.5586 - val_loss: 3.9185 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  88
# 8/8 [==============================] - 4s 587ms/step - loss: 1.7553 - accuracy: 0.5312 - val_loss: 3.9736 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  89
# 8/8 [==============================] - 4s 591ms/step - loss: 1.7639 - accuracy: 0.5703 - val_loss: 3.9486 - val_accuracy: 0.0550
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  90
# 8/8 [==============================] - 4s 588ms/step - loss: 1.6527 - accuracy: 0.5938 - val_loss: 3.9932 - val_accuracy: 0.0440
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  91
# 8/8 [==============================] - 4s 589ms/step - loss: 1.5887 - accuracy: 0.5742 - val_loss: 3.9370 - val_accuracy: 0.0550
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  92
# 8/8 [==============================] - 4s 587ms/step - loss: 1.5259 - accuracy: 0.6016 - val_loss: 3.9548 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  93
# 8/8 [==============================] - 4s 589ms/step - loss: 1.5464 - accuracy: 0.5742 - val_loss: 4.0520 - val_accuracy: 0.0460
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  94
# 8/8 [==============================] - 4s 589ms/step - loss: 1.5149 - accuracy: 0.6133 - val_loss: 4.0757 - val_accuracy: 0.0500
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  95
# 8/8 [==============================] - 4s 588ms/step - loss: 1.4636 - accuracy: 0.5938 - val_loss: 3.9953 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  96
# 8/8 [==============================] - 4s 587ms/step - loss: 1.6818 - accuracy: 0.5352 - val_loss: 4.0325 - val_accuracy: 0.0380
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  97
# 8/8 [==============================] - 4s 587ms/step - loss: 1.3592 - accuracy: 0.6680 - val_loss: 4.0283 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  98
# 8/8 [==============================] - 4s 588ms/step - loss: 1.3930 - accuracy: 0.6367 - val_loss: 4.0048 - val_accuracy: 0.0540
#
# Epoch 00001: val_loss did not improve from 3.65238
# epoch  99
# 8/8 [==============================] - 4s 588ms/step - loss: 1.5189 - accuracy: 0.6328 - val_loss: 4.0619 - val_accuracy: 0.0500
#
# Epoch 00001: val_loss did not improve from 3.65238

# %%
# plot training loss vs. validation loss over epochs
val_loss_change = []; loss_change = []
for i in range(0, len(scores)):
    val_loss_change.append(scores[i].history['val_loss'])
    loss_change.append(scores[i].history['loss'])

plt.plot(val_loss_change, label='val_loss')
plt.plot(loss_change, label='train_loss')
plt.legend(loc='upper right')
plt.show()

# %%
# loss and accuracy on validation set
age_model.evaluate(test_x, test_y, verbose=1)
# Out:
# 32/32 [==============================] - 4s 99ms/step - loss: 3.6524 - accuracy: 0.0500
# [3.6523759365081787, 0.05000000074505806]

# %%
predictions = age_model.predict(test_x)

# %%
output_indexes = np.array([i for i in range(0, 101)])
apparent_predictions = np.sum(predictions * output_indexes, axis = 1)

# %%
mae = 0
for i in range(0 ,apparent_predictions.shape[0]):
    prediction = int(apparent_predictions[i])
    actual = np.argmax(test_y[i])
    
    abs_error = abs(prediction - actual)
    mae = (mae + abs_error) / apparent_predictions.shape[0]

print("mae: ",mae)
print("instances: ",apparent_predictions.shape[0])
# Out:
# mae:  1.0010030200010029e-06
# instances:  1000

# %%
def loadImage(filepath):
    test_img = image.load_img(filepath, target_size=(224, 224))
    test_img = image.img_to_array(test_img)
    test_img = np.expand_dims(test_img, axis = 0)
    test_img /= 255
    return test_img

# %%
from keras.preprocessing import image
def image_age(photo):
  prediction = age_model.predict(loadImage(photo))
  img = image.load_img(photo)#, target_size=(224, 224))
  plt.imshow(img)
  plt.show()

  print("Predicted Age: ", np.argmax(prediction))
  apparent_age = np.round(np.sum(prediction * output_indexes, axis = 1))
  print("Apparent Age: ", int(apparent_age[0]))
  # print("Predicted Age:",((np.argmax(prediction))+ (int(apparent_age[0])))/2)

# %%
picture1 = "/content/drive/MyDrive/YOUNGER/face_old.jpeg"
picture2 = "/content/drive/MyDrive/YOUNGER/Baby-Face-Cute.jpg"
picture3 = "/content/drive/MyDrive/YOUNGER/prem_linked.jpg"
# picture4 = ''
image_age(picture1)
image_age(picture2)
image_age(picture3)
# image_age(picture4)
# Out:
# Predicted Age:  56
# Predicted Age:  22
# Predicted Age:  27

# %%
y_pos = np.arange(101)
plt.bar(y_pos, prediction[0], align='center', alpha=0.9)
plt.ylabel('percentage')
plt.title('age')
plt.show()

# %%
# create a web image upload & predict sequence
from PIL import Image
import requests
# url = 'https://freerangestock.com/sample/32745/a-pretty-young-girl-posing-with-a-white-background.jpg'
url = 'https://i.guim.co.uk/img/media/68b70e0ccc658b9b01cc7bf6a972134f2a5136e4/0_186_1900_1139/master/1900.jpg?width=1200&height=1200&quality=85&auto=format&fit=crop&s=c391df10a394dc50fafe584915c753e5'
web_photo = Image.open(requests.get(url, stream=True).raw).save("web_photo.jpg")
image_age("/content/web_photo.jpg")
# Out:
# Predicted Age:  41
# Apparent Age:  49

# %% [markdown]
# ---
#
#
# # **SUMMARY**
#
#
# ---
# ##**To be updated...**

# %% [markdown]
# # **REFERENCES**

# %% [markdown]
# 1.   https://data.vision.ee.ethz.ch/cvl/rrothe/imdb-wiki/
# 2.   https://data.vision.ee.ethz.ch/cvl/publications/papers/proceedings/eth_biwi_01229.pdf
# 3. https://sefiks.com/2019/02/13/apparent-age-and-gender-prediction-in-keras/
# 4. https://www.researchgate.net/publication/265125544_Face_Detection_without_Bells_and_Whistles
# 5. https://github.com/yu4u/age-gender-estimation
# 6. https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf
#
#
# ---
