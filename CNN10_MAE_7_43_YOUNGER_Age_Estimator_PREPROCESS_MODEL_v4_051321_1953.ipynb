# %% [markdown]
# <a href="https://colab.research.google.com/github/premonish/YOUNGER_deprecated/blob/main/CNN10_MAE_7_43_YOUNGER_Age_Estimator_PREPROCESS_MODEL_v4_051321_1953.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **YOUNGER - Age Estimator:  Preprocessing & Modeling**
# ---

# %% [markdown]
# ###**Contents**

# %% [markdown]
# [**IV. PREPROCESSING**](#scrollTo=nAuKSR5HuQCy)
#
# * 4.1 Introduction
# * 4.2 Imports
# * 4.3 Load Data
# * 4.4 Transform Data
# * 4.5 Train/Test Split
# * 4.6 Data Augmentation
#
# [**V. MODELING**](#scrollTo=QpXbL0ZoYSpN)
#
# * 5.1 CNN Architecture
# * 5.2 Transfer Learning
# * 5.3 Train the Model
# * 5.4 Model Performance
# * 5.5 Performance Visualization
# * 5.6 Unseen Data Test
#
# [**VI. SUMMARY**](#scrollTo=fRhrsD9SjrO7)
#
#
# [**VII. REFERENCES**](#scrollTo=tD6Lsmxlh3s8)
#
# [**VIII. APPENDIX**](#scrollTo=UhDT3ZLzzWxs)
#
# ---

# %% [markdown]
# # **IV. PREPROCESSING**

# %% [markdown]
# ##**4.1 Introduction**
#
# Previously, to create an age-predictor, we have completed a notebook to import data and explore its attributes: [Data Wrangling & Exploratory Data Analysis](https://github.com/premonish/YOUNGER/blob/main/notebooks/YOUNGER_Age_Estimator_WRANGLING_EDA_v2.ipynb). We took a close look at the metadata and plotted some histograms of the variable distributions. We transformed the data to extract the age of the primary face in each image from their date-of-birth and the date the photo was taken. We focused on extracting a long array of vectors of the pixel information per photo. We finished the previous phase by creating 2 arrays: 'matrix_x' with each row containing the (150,000+ pixel/image) data from each image in the dataset, and 'vector_y' containing the corresponding 'age' labels for the images.
#
# In this notebook, we will focus on Preprocessing & Modeling. In particular, we will use a Convolutional Neural Network, which is industry standard for Machine Learning image classification tasks due to its unmatched performance.
#
#
# ---

# %% [markdown]
# **Class Balance Note:**
# We decided to focus on predicting only the well represented age classes [8-80]. The dataset did not contain enough examples of other ages. Since the dataset had many examples for other ages, we decided to downsample to balance the classes.

# %% [markdown]
# **Historical Context**
# >
# > Image classification has been around for decades, however the field has been rapidly maturing in the last decade.  Since 2010, [ImageNet](https://https://en.wikipedia.org/wiki/ImageNet) Large Scale Visual Recognition Challenge (ILSVRC) is an annual competition where teams attempt to categorize thousands of images into 1,000 classes. In 2012, 'AlexNet' won the competition by a landslide and this is considered a pivotal moment in the history of deep learning, enabled by ingenious data scientists, a massive labeled dataset, and GPUs for training.

# %% [markdown]
# **PREPROCESSING** will be focused on three main sections.
#
# 1. Create Dummy Variables for categorical variables. (One-Hot Encoding)
# 2. Standardize the magnitude of numeric features using a scaler. (Scale 0-1)
# 3. Split data into testing and training datasets.
# ---

# %% [markdown]
# ## **4.2 Imports**

# %%
# !pip install tensorflow

# %%
# Create a list of currently installed python libraries for posterity
# !pip freeze > requirements.txt

# %%
### IMPORT libraries and packages ###
### I get by with a little help from my friends ###
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# deep-learning imports
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.layers import Dense, Activation, Dropout, Flatten, Input, Convolution2D, ZeroPadding2D, MaxPooling2D, Activation
from keras.layers import Conv2D, AveragePooling2D
from keras.models import Model, Sequential
from keras import metrics
from keras.models import model_from_json

# %%
# mount GDrive where the dataset is stored for Colab environment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **4.3 Load Data**
# Let's load the compressed numpy arrays from disk, extract data, and check the number of rows in our dataset.

# %%
# %%time
from numpy import asarray, savez_compressed, load
# load dict of arrays
images = np.load('/content/drive/MyDrive/YOUNGER/data5.npz', allow_pickle=True)
matrix_x = images.f.arr_0
X = matrix_x
X.shape
# Out:
# CPU times: user 12.2 s, sys: 1.94 s, total: 14.1 s
# Wall time: 14.2 s

# %%
# load the ages array 'vector_y'
ages = np.load('/content/drive/MyDrive/YOUNGER/data6.npz', allow_pickle=True)
vector_y = ages.f.arr_0
y = vector_y
y.shape
# Out:
# (5037,)

# %%
# check output matrix_x & vector_y shapes
# both matrix_x and vector_y are arrays of the same length 
assert vector_y.shape == matrix_x.shape

# %% [markdown]
# **NOTE:** I've run many tests to see how many images to include without overwhelming Google Colab's RAM.
#
# I have already upgraded to Colab Pro for this project and have been reaching the RAM limits

# %%
# Plot Age Distribution represented in the dataset
import seaborn as sns
plt.figure(figsize=(5, 3))
sns.histplot(y, color='green')
plt.title('Age Distribution')
plt.xlabel('age')
plt.ylabel('count');

# %% [markdown]
# **^ Notice the balanced classes of the input data achieved in preprocessing.**
#
# We decided to focus on predicting only the well represented age classes [8-80]. The dataset did not contain enough examples of other ages. Since the dataset had many examples for other ages, we decided to downsample to balance the classes.
#
# ---

# %% [markdown]
# ## **4.4 Transform Data**

# %% [markdown]
# **One-Hot Encoding**
#
# We need to encode the 'ages' label as categorical (binary) representations to prepare for machine learning.
# The Keras API provides a 'to_categorical()' method that can be used to one-hot encode integer data.

# %%
# classes = 101   # ages 0 to 100   # We didn't have enough training examples to predict 101 classes
classes = 73      # ages 8 to 80 (inclusive - inclusive)
target = y-8      # prepare for zero-indexed encoding - must add for prediction

# "Converts a class vector (integers) to binary class matrix." 
target_classes = keras.utils.to_categorical(target, classes)

# %% [markdown]
# **Reshaping the Data**
#
# We must reshape the data into the standard input array shape of a 'rank 4 tensor' to prepare for the Tensorflow CNN.
#
# (b, w, h, c) : (batch, width, height, channels)

# %%
features = []
for i in range(0, len(X)):
    features.append(X[i])
features = np.array(features)
features = features.reshape(len(X),224,224,3)
features.shape
# Out:
# (5037, 224, 224, 3)

# %% [markdown]
# **Scale the Data**
#
# Each of the pixel values range from 0-255. Let's scale the values to from 0-1 by dividing each value by 255. Interestingly, we are actually performing this operation virtually instantly 150,528 times per image (times the number of images).

# %%
features /= 255        # scale down pixel values to range [0, 1]
print("The maximum value in our dataset is:", features.max())
# Out:
# The maximum value in our dataset is: 1.0

# %% [markdown]
# ---

# %% [markdown]
# ## **4.5 Train/Test Split**
# We will divide the dataset randomly into training data and test data (80/20). We will later perform data augmentation on only the training set to help balance the classes of ages in the dataset.

# %%
# train/ test split
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(features, target_classes, test_size=0.30, random_state=42, stratify=target_classes)

# %%
print("X_train shape =" ,train_x.shape) 
print("X_test  shape ="  ,test_x.shape)
print('- - - - - - - - - - - - - - - - - -')
print("y_train shape =" ,train_y.shape)
print("y_test  shape ="  ,test_y.shape)
# Out:
# X_train shape = (3525, 224, 224, 3)
# X_test  shape = (1512, 224, 224, 3)
# - - - - - - - - - - - - - - - - - -
# y_train shape = (3525, 73)
# y_test  shape = (1512, 73)

# %% [markdown]
# Now that we have one-hot encoded the target classes, shaped the input data into tensor-like shapes, scaled the data to 0-1, and split the dataset into training and test subsets, we are ready to move onto modeling.

# %% [markdown]
# ## **4.5 Data Augmentation**
# We will apply some data tranformations to add variation to the training set during when feeding the data into the CNN. We will use random horizontal flipping, random rotations and slight random zooms to increase the diversity of the training data with the intention to reduce overfitting.

# %%
# data augmentation using TensorFlow & Keras to be applied at the start of the CNN
from tensorflow.keras import layers
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(224,224,3)), # Randomly flip each image horizontally and vertically.
    layers.experimental.preprocessing.RandomRotation(0.1),                               # Randomly rotate each image.
    layers.experimental.preprocessing.RandomZoom(0.1),                                   # Randomly zoom each image during training.  
    # layers.experimental.preprocessing.RandomContrast(0.1)
  ]
)

# %% [markdown]
# ---

# %% [markdown]
# # **V. MODELING**

# %% [markdown]
# **MODELING** will focus on the following four phases.
# 1. Train the models on the dataset (fit)
# 2. Review model performance metrics
# 3. Iterate over other models
# 4. Identify the final model
#
#
# ---

# %% [markdown]
# ## **5.1 CNN Architecture**
#
# I'll start by using an established architecture titled "[VGG-Face](https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf)" effective for facial recognition and building custom layers on top. This model was created by the Visual Geometry Group, at the University of Oxford to recognize 2,622 celebrities. Facial recognition is a more complex task than age prediction, yet the features extracted from many of the early layers of this model can be useful to our problem.
#
# "These models can be used for non-commercial research purposes under [Creative Commons Attribution License](https://creativecommons.org/licenses/by-nc/4.0/)."
#
# [VGGFace Github](https://github.com/rcmalli/keras-vggface)

# %% [markdown]
# ![vgg_arch.PNG](data:image/png;base64,...)

# %% [markdown]
# **^ VGG-Face Architecture** The first 8 blocks are convolutional. The last 3 blocks are Fully Connected (fc). All convolution layers are followed by a ReLU (recitified linear unit) activation later. A softmax layer predicts probabilities of the labels.

# %%
#VGG-Face model
model = Sequential(data_augmentation)                    # apply data augmentation
model.add(ZeroPadding2D((1,1),input_shape=(224,224, 3)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(Convolution2D(4096, (7, 7), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(4096, (1, 1), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(2622, (1, 1)))
model.add(Flatten())
model.add(Activation('softmax'))

# %% [markdown]
# ---

# %% [markdown]
# ## **5.2 Transfer Learning**
#
# Transfer learning allows us to use weights that have already been trained on a massive dataset (2.6M images in this case). For similar tasks, we can simply freeze the weights for many of the early layers. However, the later layers in the model will need to trained and tuned for our specific task.
#
# **Trained weights source:**
# https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf

# %%
# load the pre-trained weights to take advantage of transfer learning
model.load_weights('/content/drive/MyDrive/YOUNGER/vgg_face_weights.h5')

# %% [markdown]
# **To take advantage of transfer learning, we will freeze layers with trained weights. We will custom tune the last four layers for our age predictor based on our training set.**

# %%
# freeze layers to use transfer learning effectively
for layer in model.layers[:-7]:
  layer.trainable = False

# add custom layers to predict on unique dataset and problem 
base_model_output = Sequential()

### TESTING
from tensorflow.keras.regularizers import Regularizer
# base_model_output = Dense(512, activation = 'relu', use_bias=True, kernel_regularizer =tf.keras.regularizers.l1( l=0.01)),
# base_model_output = Dense(73, activation='softmax', use_bias=True)
base_model_output = Dense(73, name='predictions', use_bias=True, kernel_regularizer =tf.keras.regularizers.l2( l=0.1))(model.layers[-4].output)
###

# base_model_output = Convolution2D(73, (1, 1), name='predictions')(model.layers[-4].output)
base_model_output = Flatten()(base_model_output)
base_model_output = Dense(73, 'softmax', use_bias=True)(base_model_output) #TEST
# base_model_output = Activation('softmax')(base_model_output)

age_model = Model(inputs=model.input, outputs=base_model_output)

# %%
#check trainable layers
if False:
    for layer in model.layers:
        print(layer, layer.trainable)
    
    print("------------------------")
    for layer in age_model.layers:
        print(layer, layer.trainable)

# %% [markdown]
# **Compile Model**
#
# Categorical crossentropy is an appropriate loss function for multi-class classification problems.
#
# We will use an 'Adam' optimizer with a learning rate of 0.0007.

# %%
# Stochastic Gradient Descent = sgd
# compile the model
# sgd = keras.optimizers.SGD(lr=1e-3, decay=1e-6, momentum=.9, nesterov=True)

opt = keras.optimizers.Adam(learning_rate=0.0007,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    name="Adam"
)

# 'categorical_crossentropy' is an appropriate loss function for a multi-class classification problem such as ours
age_model.compile(loss='categorical_crossentropy'
                  , optimizer = opt
                  # , optimizer = sgd
                  , metrics=['accuracy']
                 )

# %% [markdown]
# **Model Checkpoint**
#
# Validation Loss is our key performance metric. We create a checkpointer which automatically saves the best model based on improved 'val_loss' performance. We can later use the best pre-trained model to measure the performance of the model on unseen data.

# %%
# create checkpoint which saves the best model based on loss on the validation data 
# if the validation loss decreases, the model will be saved as a checkpoint
checkpointer = ModelCheckpoint(
    # filepath='/content/classification_age_model.hdf5'
    filepath='/content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5'
    , monitor = "val_loss"
    , verbose=1
    , save_best_only=True
    , mode = 'min'
    # , mode = 'auto'
)

# %% [markdown]
# **Early Stopping**
#
# Early Stopping will notice when the validation loss is not improving  and it will stop the training to prevent overfitting.

# %%
# enable Early Stopping 
from tensorflow.keras.callbacks import EarlyStopping
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5)

# %% [markdown]
# **Tensorboard**
#
# Tensorboard allows us to experiment, visualizing changes in model details (hyperparameters) and perfomance metrics.

# %%
#tensorboard
# %load_ext tensorboard
import datetime

# %%
# instantiate TensorBoard and define callback variable
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %% [markdown]
# **Save Performance Metrics**
#
# Kera's 'History' callback allows us to track performance metrics which we can later visualize.

# %%
# record model performance
from keras.callbacks import History 
history = History()

# %%
# Clear any logs from previous runs - TensorBoard
! rm -rf ./logs/

# %% [markdown]
# ---

# %% [markdown]
# ##**5.3 Train the Model**
#
# Training the model is where the magic happens. We will train our model for a given number of epochs with a given batchsize. We have tried many iterations with various batchsizes and various numbers of epochs to reach allow proper training while avoiding overfitting. Our primary performance metric is validation loss. As the model progresses through epochs, we want the validation loss to decrease at a steady pace.
#
# We will save our best model. In the future, we can simply use the saved model to predict on new data.

# %%
# set batch size and # of epochs
# fit the model on training set & validate on the test set
epochs = 200           # original = 250
batch_size = 128       # original = 256

enableFit = True

if enableFit:
    for i in range(epochs):
        print("epoch ",i)
        ix_train = np.random.choice(train_x.shape[0], size=batch_size)
        
        score = age_model.fit(
            train_x[ix_train], train_y[ix_train],
            epochs=1,
            validation_data=(test_x, test_y),
            callbacks=[tensorboard_callback, checkpointer, callback, history])
        
    #restore the best weights
    from keras.models import load_model
    age_model = load_model('/content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5')
    age_model.save_weights('/content/drive/MyDrive/YOUNGER/age_model_weights_6.h5')
        
else:
    # pre-trained weights for age prediction
    age_model.load_weights("/content/drive/MyDrive/YOUNGER/age_model_weights_6.h5")
# Out:
# epoch  0
# 4/4 [==============================] - 16s 2s/step - loss: 17.9046 - accuracy: 0.0167 - val_loss: 15.6708 - val_accuracy: 0.0205
#
# Epoch 00001: val_loss improved from inf to 15.67082, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  1
# 4/4 [==============================] - 6s 2s/step - loss: 14.7307 - accuracy: 0.0391 - val_loss: 13.2553 - val_accuracy: 0.0112
#
# Epoch 00001: val_loss improved from 15.67082 to 13.25530, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  2
# 4/4 [==============================] - 6s 2s/step - loss: 12.4729 - accuracy: 0.0156 - val_loss: 11.3364 - val_accuracy: 0.0159
#
# Epoch 00001: val_loss improved from 13.25530 to 11.33637, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  3
# 4/4 [==============================] - 6s 2s/step - loss: 10.7772 - accuracy: 0.0312 - val_loss: 9.7047 - val_accuracy: 0.0152
#
# Epoch 00001: val_loss improved from 11.33637 to 9.70471, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  4
# 4/4 [==============================] - 6s 2s/step - loss: 9.2063 - accuracy: 0.0156 - val_loss: 8.4166 - val_accuracy: 0.0179
#
# Epoch 00001: val_loss improved from 9.70471 to 8.41660, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  5
# 4/4 [==============================] - 6s 2s/step - loss: 8.0167 - accuracy: 0.0156 - val_loss: 7.4104 - val_accuracy: 0.0159
#
# Epoch 00001: val_loss improved from 8.41660 to 7.41036, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  6
# 4/4 [==============================] - 6s 2s/step - loss: 7.1398 - accuracy: 0.0078 - val_loss: 6.6141 - val_accuracy: 0.0317
#
# Epoch 00001: val_loss improved from 7.41036 to 6.61407, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  7
# 4/4 [==============================] - 6s 2s/step - loss: 6.3534 - accuracy: 0.0234 - val_loss: 6.0154 - val_accuracy: 0.0218
#
# Epoch 00001: val_loss improved from 6.61407 to 6.01543, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  8
# 4/4 [==============================] - 6s 2s/step - loss: 5.8456 - accuracy: 0.0000e+00 - val_loss: 5.5629 - val_accuracy: 0.0205
#
# Epoch 00001: val_loss improved from 6.01543 to 5.56290, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  9
# 4/4 [==============================] - 6s 2s/step - loss: 5.3914 - accuracy: 0.0078 - val_loss: 5.2150 - val_accuracy: 0.0265
#
# Epoch 00001: val_loss improved from 5.56290 to 5.21502, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  10
# 4/4 [==============================] - 6s 2s/step - loss: 5.0680 - accuracy: 0.0234 - val_loss: 4.9689 - val_accuracy: 0.0284
#
# Epoch 00001: val_loss improved from 5.21502 to 4.96892, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  11
# 4/4 [==============================] - 6s 2s/step - loss: 4.8665 - accuracy: 0.0312 - val_loss: 4.7822 - val_accuracy: 0.0265
#
# Epoch 00001: val_loss improved from 4.96892 to 4.78219, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  12
# 4/4 [==============================] - 6s 2s/step - loss: 4.6925 - accuracy: 0.0469 - val_loss: 4.6377 - val_accuracy: 0.0218
#
# Epoch 00001: val_loss improved from 4.78219 to 4.63768, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  13
# 4/4 [==============================] - 6s 2s/step - loss: 4.6230 - accuracy: 0.0156 - val_loss: 4.5167 - val_accuracy: 0.0251
#
# Epoch 00001: val_loss improved from 4.63768 to 4.51670, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  14
# 4/4 [==============================] - 6s 2s/step - loss: 4.4761 - accuracy: 0.0391 - val_loss: 4.4208 - val_accuracy: 0.0311
#
# Epoch 00001: val_loss improved from 4.51670 to 4.42078, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  15
# 4/4 [==============================] - 6s 2s/step - loss: 4.4005 - accuracy: 0.0312 - val_loss: 4.3738 - val_accuracy: 0.0291
#
# Epoch 00001: val_loss improved from 4.42078 to 4.37384, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  16
# 4/4 [==============================] - 6s 2s/step - loss: 4.3830 - accuracy: 0.0312 - val_loss: 4.3342 - val_accuracy: 0.0258
#
# Epoch 00001: val_loss improved from 4.37384 to 4.33420, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  17
# 4/4 [==============================] - 6s 2s/step - loss: 4.2501 - accuracy: 0.0234 - val_loss: 4.2900 - val_accuracy: 0.0218
#
# Epoch 00001: val_loss improved from 4.33420 to 4.28997, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  18
# 4/4 [==============================] - 6s 2s/step - loss: 4.2387 - accuracy: 0.0156 - val_loss: 4.2638 - val_accuracy: 0.0258
#
# Epoch 00001: val_loss improved from 4.28997 to 4.26377, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  19
# 4/4 [==============================] - 6s 2s/step - loss: 4.3801 - accuracy: 0.0312 - val_loss: 4.2163 - val_accuracy: 0.0265
#
# Epoch 00001: val_loss improved from 4.26377 to 4.21634, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  20
# 4/4 [==============================] - 6s 2s/step - loss: 4.2722 - accuracy: 0.0234 - val_loss: 4.1939 - val_accuracy: 0.0278
#
# Epoch 00001: val_loss improved from 4.21634 to 4.19392, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  21
# 4/4 [==============================] - 6s 2s/step - loss: 4.2486 - accuracy: 0.0156 - val_loss: 4.1675 - val_accuracy: 0.0311
#
# Epoch 00001: val_loss improved from 4.19392 to 4.16751, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  22
# 4/4 [==============================] - 6s 2s/step - loss: 4.2264 - accuracy: 0.0234 - val_loss: 4.1709 - val_accuracy: 0.0271
#
# Epoch 00001: val_loss did not improve from 4.16751
# epoch  23
# 4/4 [==============================] - 6s 2s/step - loss: 4.2415 - accuracy: 0.0391 - val_loss: 4.1286 - val_accuracy: 0.0291
#
# Epoch 00001: val_loss improved from 4.16751 to 4.12861, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  24
# 4/4 [==============================] - 6s 2s/step - loss: 4.1217 - accuracy: 0.0312 - val_loss: 4.0999 - val_accuracy: 0.0284
#
# Epoch 00001: val_loss improved from 4.12861 to 4.09991, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  25
# 4/4 [==============================] - 6s 2s/step - loss: 4.0357 - accuracy: 0.0625 - val_loss: 4.1076 - val_accuracy: 0.0291
#
# Epoch 00001: val_loss did not improve from 4.09991
# epoch  26
# 4/4 [==============================] - 6s 2s/step - loss: 4.1742 - accuracy: 0.0156 - val_loss: 4.0822 - val_accuracy: 0.0331
#
# Epoch 00001: val_loss improved from 4.09991 to 4.08223, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  27
# 4/4 [==============================] - 6s 2s/step - loss: 4.1043 - accuracy: 0.0156 - val_loss: 4.0527 - val_accuracy: 0.0377
#
# Epoch 00001: val_loss improved from 4.08223 to 4.05271, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  28
# 4/4 [==============================] - 6s 2s/step - loss: 4.1208 - accuracy: 0.0312 - val_loss: 4.0532 - val_accuracy: 0.0331
#
# Epoch 00001: val_loss did not improve from 4.05271
# epoch  29
# 4/4 [==============================] - 6s 2s/step - loss: 4.0281 - accuracy: 0.0312 - val_loss: 4.0490 - val_accuracy: 0.0410
#
# Epoch 00001: val_loss improved from 4.05271 to 4.04902, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  30
# 4/4 [==============================] - 6s 2s/step - loss: 4.0450 - accuracy: 0.0234 - val_loss: 4.0413 - val_accuracy: 0.0417
#
# Epoch 00001: val_loss improved from 4.04902 to 4.04128, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  31
# 4/4 [==============================] - 6s 2s/step - loss: 4.1228 - accuracy: 0.0156 - val_loss: 4.0289 - val_accuracy: 0.0304
#
# Epoch 00001: val_loss improved from 4.04128 to 4.02886, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  32
# 4/4 [==============================] - 6s 2s/step - loss: 4.0367 - accuracy: 0.0391 - val_loss: 4.0262 - val_accuracy: 0.0304
#
# Epoch 00001: val_loss improved from 4.02886 to 4.02621, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  33
# 4/4 [==============================] - 6s 2s/step - loss: 4.1747 - accuracy: 0.0234 - val_loss: 4.0035 - val_accuracy: 0.0351
#
# Epoch 00001: val_loss improved from 4.02621 to 4.00352, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  34
# 4/4 [==============================] - 6s 2s/step - loss: 4.1104 - accuracy: 0.0312 - val_loss: 3.9875 - val_accuracy: 0.0403
#
# Epoch 00001: val_loss improved from 4.00352 to 3.98752, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  35
# 4/4 [==============================] - 6s 2s/step - loss: 4.0203 - accuracy: 0.0391 - val_loss: 4.0177 - val_accuracy: 0.0337
#
# Epoch 00001: val_loss did not improve from 3.98752
# epoch  36
# 4/4 [==============================] - 6s 2s/step - loss: 3.9605 - accuracy: 0.0312 - val_loss: 3.9882 - val_accuracy: 0.0317
#
# Epoch 00001: val_loss did not improve from 3.98752
# epoch  37
# 4/4 [==============================] - 6s 2s/step - loss: 4.0148 - accuracy: 0.0312 - val_loss: 3.9948 - val_accuracy: 0.0265
#
# Epoch 00001: val_loss did not improve from 3.98752
# epoch  38
# 4/4 [==============================] - 6s 2s/step - loss: 3.9703 - accuracy: 0.0234 - val_loss: 3.9620 - val_accuracy: 0.0351
#
# Epoch 00001: val_loss improved from 3.98752 to 3.96201, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  39
# 4/4 [==============================] - 6s 2s/step - loss: 4.0865 - accuracy: 0.0312 - val_loss: 3.9441 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss improved from 3.96201 to 3.94410, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  40
# 4/4 [==============================] - 6s 2s/step - loss: 3.9613 - accuracy: 0.0469 - val_loss: 3.9702 - val_accuracy: 0.0370
#
# Epoch 00001: val_loss did not improve from 3.94410
# epoch  41
# 4/4 [==============================] - 6s 2s/step - loss: 4.0191 - accuracy: 0.0469 - val_loss: 3.9363 - val_accuracy: 0.0437
#
# Epoch 00001: val_loss improved from 3.94410 to 3.93625, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  42
# 4/4 [==============================] - 6s 2s/step - loss: 4.0410 - accuracy: 0.0469 - val_loss: 3.9290 - val_accuracy: 0.0370
#
# Epoch 00001: val_loss improved from 3.93625 to 3.92901, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  43
# 4/4 [==============================] - 6s 2s/step - loss: 3.9131 - accuracy: 0.0078 - val_loss: 3.9448 - val_accuracy: 0.0443
#
# Epoch 00001: val_loss did not improve from 3.92901
# epoch  44
# 4/4 [==============================] - 6s 2s/step - loss: 3.9633 - accuracy: 0.0312 - val_loss: 3.9410 - val_accuracy: 0.0437
#
# Epoch 00001: val_loss did not improve from 3.92901
# epoch  45
# 4/4 [==============================] - 6s 2s/step - loss: 4.0125 - accuracy: 0.0469 - val_loss: 3.9159 - val_accuracy: 0.0423
#
# Epoch 00001: val_loss improved from 3.92901 to 3.91594, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  46
# 4/4 [==============================] - 6s 2s/step - loss: 3.9064 - accuracy: 0.0078 - val_loss: 3.9053 - val_accuracy: 0.0423
#
# Epoch 00001: val_loss improved from 3.91594 to 3.90534, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  47
# 4/4 [==============================] - 6s 2s/step - loss: 3.9488 - accuracy: 0.0391 - val_loss: 3.8921 - val_accuracy: 0.0476
#
# Epoch 00001: val_loss improved from 3.90534 to 3.89215, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  48
# 4/4 [==============================] - 6s 2s/step - loss: 3.9198 - accuracy: 0.0469 - val_loss: 3.8862 - val_accuracy: 0.0437
#
# Epoch 00001: val_loss improved from 3.89215 to 3.88622, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  49
# 4/4 [==============================] - 6s 2s/step - loss: 4.1357 - accuracy: 0.0391 - val_loss: 3.8982 - val_accuracy: 0.0397
#
# Epoch 00001: val_loss did not improve from 3.88622
# epoch  50
# 4/4 [==============================] - 6s 2s/step - loss: 3.8895 - accuracy: 0.0469 - val_loss: 3.8864 - val_accuracy: 0.0390
#
# Epoch 00001: val_loss did not improve from 3.88622
# epoch  51
# 4/4 [==============================] - 6s 2s/step - loss: 4.0660 - accuracy: 0.0234 - val_loss: 3.8818 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss improved from 3.88622 to 3.88180, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  52
# 4/4 [==============================] - 6s 2s/step - loss: 3.9892 - accuracy: 0.0234 - val_loss: 3.8975 - val_accuracy: 0.0337
#
# Epoch 00001: val_loss did not improve from 3.88180
# epoch  53
# 4/4 [==============================] - 6s 2s/step - loss: 3.8632 - accuracy: 0.0625 - val_loss: 3.8749 - val_accuracy: 0.0417
#
# Epoch 00001: val_loss improved from 3.88180 to 3.87486, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  54
# 4/4 [==============================] - 6s 2s/step - loss: 3.9257 - accuracy: 0.0469 - val_loss: 3.9140 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.87486
# epoch  55
# 4/4 [==============================] - 6s 2s/step - loss: 3.8697 - accuracy: 0.0391 - val_loss: 3.8670 - val_accuracy: 0.0437
#
# Epoch 00001: val_loss improved from 3.87486 to 3.86701, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  56
# 4/4 [==============================] - 6s 2s/step - loss: 3.8496 - accuracy: 0.0625 - val_loss: 3.8673 - val_accuracy: 0.0456
#
# Epoch 00001: val_loss did not improve from 3.86701
# epoch  57
# 4/4 [==============================] - 6s 2s/step - loss: 3.9589 - accuracy: 0.0469 - val_loss: 3.8841 - val_accuracy: 0.0489
#
# Epoch 00001: val_loss did not improve from 3.86701
# epoch  58
# 4/4 [==============================] - 6s 2s/step - loss: 3.9720 - accuracy: 0.0391 - val_loss: 3.8838 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.86701
# epoch  59
# 4/4 [==============================] - 6s 2s/step - loss: 3.9201 - accuracy: 0.0391 - val_loss: 3.8338 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss improved from 3.86701 to 3.83380, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  60
# 4/4 [==============================] - 6s 2s/step - loss: 3.9332 - accuracy: 0.0312 - val_loss: 3.8444 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss did not improve from 3.83380
# epoch  61
# 4/4 [==============================] - 6s 2s/step - loss: 3.8854 - accuracy: 0.0234 - val_loss: 3.8374 - val_accuracy: 0.0417
#
# Epoch 00001: val_loss did not improve from 3.83380
# epoch  62
# 4/4 [==============================] - 6s 2s/step - loss: 3.8415 - accuracy: 0.0156 - val_loss: 3.8265 - val_accuracy: 0.0417
#
# Epoch 00001: val_loss improved from 3.83380 to 3.82648, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  63
# 4/4 [==============================] - 6s 2s/step - loss: 3.8525 - accuracy: 0.0781 - val_loss: 3.8179 - val_accuracy: 0.0536
#
# Epoch 00001: val_loss improved from 3.82648 to 3.81790, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  64
# 4/4 [==============================] - 6s 2s/step - loss: 3.8799 - accuracy: 0.0469 - val_loss: 3.8396 - val_accuracy: 0.0496
#
# Epoch 00001: val_loss did not improve from 3.81790
# epoch  65
# 4/4 [==============================] - 6s 2s/step - loss: 3.8661 - accuracy: 0.0391 - val_loss: 3.8251 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss did not improve from 3.81790
# epoch  66
# 4/4 [==============================] - 6s 2s/step - loss: 3.8890 - accuracy: 0.0625 - val_loss: 3.8299 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.81790
# epoch  67
# 4/4 [==============================] - 6s 2s/step - loss: 3.7744 - accuracy: 0.0703 - val_loss: 3.8350 - val_accuracy: 0.0443
#
# Epoch 00001: val_loss did not improve from 3.81790
# epoch  68
# 4/4 [==============================] - 6s 2s/step - loss: 3.8781 - accuracy: 0.0469 - val_loss: 3.8437 - val_accuracy: 0.0463
#
# Epoch 00001: val_loss did not improve from 3.81790
# epoch  69
# 4/4 [==============================] - 6s 2s/step - loss: 3.9050 - accuracy: 0.0312 - val_loss: 3.8312 - val_accuracy: 0.0456
#
# Epoch 00001: val_loss did not improve from 3.81790
# epoch  70
# 4/4 [==============================] - 6s 2s/step - loss: 3.9235 - accuracy: 0.0078 - val_loss: 3.8151 - val_accuracy: 0.0483
#
# Epoch 00001: val_loss improved from 3.81790 to 3.81509, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  71
# 4/4 [==============================] - 6s 2s/step - loss: 3.8293 - accuracy: 0.0312 - val_loss: 3.8051 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss improved from 3.81509 to 3.80510, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  72
# 4/4 [==============================] - 6s 2s/step - loss: 3.7352 - accuracy: 0.1250 - val_loss: 3.8150 - val_accuracy: 0.0569
#
# Epoch 00001: val_loss did not improve from 3.80510
# epoch  73
# 4/4 [==============================] - 6s 2s/step - loss: 3.7754 - accuracy: 0.0781 - val_loss: 3.8077 - val_accuracy: 0.0542
#
# Epoch 00001: val_loss did not improve from 3.80510
# epoch  74
# 4/4 [==============================] - 6s 2s/step - loss: 3.8782 - accuracy: 0.0625 - val_loss: 3.7878 - val_accuracy: 0.0589
#
# Epoch 00001: val_loss improved from 3.80510 to 3.78780, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  75
# 4/4 [==============================] - 6s 2s/step - loss: 3.8808 - accuracy: 0.0781 - val_loss: 3.7869 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss improved from 3.78780 to 3.78690, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  76
# 4/4 [==============================] - 6s 2s/step - loss: 3.8565 - accuracy: 0.0391 - val_loss: 3.7905 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss did not improve from 3.78690
# epoch  77
# 4/4 [==============================] - 6s 2s/step - loss: 3.7470 - accuracy: 0.0625 - val_loss: 3.7910 - val_accuracy: 0.0476
#
# Epoch 00001: val_loss did not improve from 3.78690
# epoch  78
# 4/4 [==============================] - 6s 2s/step - loss: 3.7963 - accuracy: 0.0234 - val_loss: 3.7804 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss improved from 3.78690 to 3.78036, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  79
# 4/4 [==============================] - 6s 2s/step - loss: 3.7589 - accuracy: 0.0703 - val_loss: 3.7790 - val_accuracy: 0.0615
#
# Epoch 00001: val_loss improved from 3.78036 to 3.77904, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  80
# 4/4 [==============================] - 6s 2s/step - loss: 3.8723 - accuracy: 0.0391 - val_loss: 3.7655 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss improved from 3.77904 to 3.76546, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  81
# 4/4 [==============================] - 6s 2s/step - loss: 3.8658 - accuracy: 0.0469 - val_loss: 3.7722 - val_accuracy: 0.0476
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  82
# 4/4 [==============================] - 6s 2s/step - loss: 3.7484 - accuracy: 0.0625 - val_loss: 3.7915 - val_accuracy: 0.0595
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  83
# 4/4 [==============================] - 6s 2s/step - loss: 3.7995 - accuracy: 0.0312 - val_loss: 3.7940 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  84
# 4/4 [==============================] - 6s 2s/step - loss: 3.7028 - accuracy: 0.0391 - val_loss: 3.8224 - val_accuracy: 0.0509
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  85
# 4/4 [==============================] - 6s 2s/step - loss: 3.7343 - accuracy: 0.0781 - val_loss: 3.8224 - val_accuracy: 0.0483
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  86
# 4/4 [==============================] - 6s 2s/step - loss: 3.9206 - accuracy: 0.0703 - val_loss: 3.7868 - val_accuracy: 0.0483
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  87
# 4/4 [==============================] - 6s 2s/step - loss: 3.8583 - accuracy: 0.0547 - val_loss: 3.8031 - val_accuracy: 0.0489
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  88
# 4/4 [==============================] - 6s 2s/step - loss: 3.9119 - accuracy: 0.0234 - val_loss: 3.8034 - val_accuracy: 0.0489
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  89
# 4/4 [==============================] - 6s 2s/step - loss: 3.6738 - accuracy: 0.0781 - val_loss: 3.7710 - val_accuracy: 0.0536
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  90
# 4/4 [==============================] - 6s 2s/step - loss: 3.8493 - accuracy: 0.1016 - val_loss: 3.7919 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  91
# 4/4 [==============================] - 6s 2s/step - loss: 3.7875 - accuracy: 0.0234 - val_loss: 3.7957 - val_accuracy: 0.0516
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  92
# 4/4 [==============================] - 6s 2s/step - loss: 3.8899 - accuracy: 0.0703 - val_loss: 3.8056 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  93
# 4/4 [==============================] - 6s 2s/step - loss: 3.7220 - accuracy: 0.0781 - val_loss: 3.7977 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  94
# 4/4 [==============================] - 6s 2s/step - loss: 3.7444 - accuracy: 0.0938 - val_loss: 3.7860 - val_accuracy: 0.0503
#
# Epoch 00001: val_loss did not improve from 3.76546
# epoch  95
# 4/4 [==============================] - 6s 2s/step - loss: 3.6976 - accuracy: 0.0547 - val_loss: 3.7643 - val_accuracy: 0.0476
#
# Epoch 00001: val_loss improved from 3.76546 to 3.76428, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  96
# 4/4 [==============================] - 6s 2s/step - loss: 3.7846 - accuracy: 0.0391 - val_loss: 3.7623 - val_accuracy: 0.0489
#
# Epoch 00001: val_loss improved from 3.76428 to 3.76227, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  97
# 4/4 [==============================] - 6s 2s/step - loss: 3.9188 - accuracy: 0.0000e+00 - val_loss: 3.7614 - val_accuracy: 0.0456
#
# Epoch 00001: val_loss improved from 3.76227 to 3.76142, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  98
# 4/4 [==============================] - 6s 2s/step - loss: 3.8984 - accuracy: 0.0156 - val_loss: 3.7738 - val_accuracy: 0.0403
#
# Epoch 00001: val_loss did not improve from 3.76142
# epoch  99
# 4/4 [==============================] - 6s 2s/step - loss: 3.6947 - accuracy: 0.0703 - val_loss: 3.7647 - val_accuracy: 0.0384
#
# Epoch 00001: val_loss did not improve from 3.76142
# epoch  100
# 4/4 [==============================] - 6s 2s/step - loss: 3.7364 - accuracy: 0.0469 - val_loss: 3.7930 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.76142
# epoch  101
# 4/4 [==============================] - 6s 2s/step - loss: 3.8259 - accuracy: 0.0312 - val_loss: 3.8156 - val_accuracy: 0.0476
#
# Epoch 00001: val_loss did not improve from 3.76142
# epoch  102
# 4/4 [==============================] - 6s 2s/step - loss: 3.8812 - accuracy: 0.0625 - val_loss: 3.7890 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss did not improve from 3.76142
# epoch  103
# 4/4 [==============================] - 6s 2s/step - loss: 3.9010 - accuracy: 0.0547 - val_loss: 3.7655 - val_accuracy: 0.0542
#
# Epoch 00001: val_loss did not improve from 3.76142
# epoch  104
# 4/4 [==============================] - 6s 2s/step - loss: 3.7174 - accuracy: 0.0391 - val_loss: 3.7597 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss improved from 3.76142 to 3.75971, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  105
# 4/4 [==============================] - 6s 2s/step - loss: 3.8897 - accuracy: 0.0391 - val_loss: 3.7710 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss did not improve from 3.75971
# epoch  106
# 4/4 [==============================] - 6s 2s/step - loss: 3.6964 - accuracy: 0.0625 - val_loss: 3.7480 - val_accuracy: 0.0437
#
# Epoch 00001: val_loss improved from 3.75971 to 3.74803, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  107
# 4/4 [==============================] - 6s 2s/step - loss: 3.8097 - accuracy: 0.0938 - val_loss: 3.7661 - val_accuracy: 0.0456
#
# Epoch 00001: val_loss did not improve from 3.74803
# epoch  108
# 4/4 [==============================] - 6s 2s/step - loss: 3.7543 - accuracy: 0.0469 - val_loss: 3.7635 - val_accuracy: 0.0529
#
# Epoch 00001: val_loss did not improve from 3.74803
# epoch  109
# 4/4 [==============================] - 6s 2s/step - loss: 3.7941 - accuracy: 0.0391 - val_loss: 3.7622 - val_accuracy: 0.0456
#
# Epoch 00001: val_loss did not improve from 3.74803
# epoch  110
# 4/4 [==============================] - 6s 2s/step - loss: 3.7096 - accuracy: 0.0547 - val_loss: 3.7431 - val_accuracy: 0.0476
#
# Epoch 00001: val_loss improved from 3.74803 to 3.74306, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  111
# 4/4 [==============================] - 6s 2s/step - loss: 3.7332 - accuracy: 0.0859 - val_loss: 3.7393 - val_accuracy: 0.0496
#
# Epoch 00001: val_loss improved from 3.74306 to 3.73927, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  112
# 4/4 [==============================] - 6s 2s/step - loss: 3.8111 - accuracy: 0.0625 - val_loss: 3.7208 - val_accuracy: 0.0529
#
# Epoch 00001: val_loss improved from 3.73927 to 3.72078, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  113
# 4/4 [==============================] - 6s 2s/step - loss: 3.6685 - accuracy: 0.0547 - val_loss: 3.7205 - val_accuracy: 0.0602
#
# Epoch 00001: val_loss improved from 3.72078 to 3.72053, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  114
# 4/4 [==============================] - 6s 2s/step - loss: 3.5508 - accuracy: 0.0781 - val_loss: 3.7354 - val_accuracy: 0.0622
#
# Epoch 00001: val_loss did not improve from 3.72053
# epoch  115
# 4/4 [==============================] - 6s 2s/step - loss: 3.7143 - accuracy: 0.0781 - val_loss: 3.7258 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.72053
# epoch  116
# 4/4 [==============================] - 6s 2s/step - loss: 3.8633 - accuracy: 0.0312 - val_loss: 3.7490 - val_accuracy: 0.0529
#
# Epoch 00001: val_loss did not improve from 3.72053
# epoch  117
# 4/4 [==============================] - 6s 2s/step - loss: 3.8206 - accuracy: 0.0156 - val_loss: 3.7253 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.72053
# epoch  118
# 4/4 [==============================] - 6s 2s/step - loss: 3.8100 - accuracy: 0.0391 - val_loss: 3.7260 - val_accuracy: 0.0516
#
# Epoch 00001: val_loss did not improve from 3.72053
# epoch  119
# 4/4 [==============================] - 6s 2s/step - loss: 3.6379 - accuracy: 0.0859 - val_loss: 3.7489 - val_accuracy: 0.0542
#
# Epoch 00001: val_loss did not improve from 3.72053
# epoch  120
# 4/4 [==============================] - 6s 2s/step - loss: 3.7375 - accuracy: 0.0547 - val_loss: 3.7538 - val_accuracy: 0.0714
#
# Epoch 00001: val_loss did not improve from 3.72053
# epoch  121
# 4/4 [==============================] - 6s 2s/step - loss: 3.7651 - accuracy: 0.0469 - val_loss: 3.7482 - val_accuracy: 0.0622
#
# Epoch 00001: val_loss did not improve from 3.72053
# epoch  122
# 4/4 [==============================] - 6s 2s/step - loss: 3.7572 - accuracy: 0.0469 - val_loss: 3.7361 - val_accuracy: 0.0589
#
# Epoch 00001: val_loss did not improve from 3.72053
# epoch  123
# 4/4 [==============================] - 6s 2s/step - loss: 3.8292 - accuracy: 0.0547 - val_loss: 3.7227 - val_accuracy: 0.0476
#
# Epoch 00001: val_loss did not improve from 3.72053
# epoch  124
# 4/4 [==============================] - 6s 2s/step - loss: 3.8223 - accuracy: 0.0234 - val_loss: 3.7165 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss improved from 3.72053 to 3.71652, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  125
# 4/4 [==============================] - 6s 2s/step - loss: 3.7938 - accuracy: 0.0469 - val_loss: 3.7223 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  126
# 4/4 [==============================] - 6s 2s/step - loss: 3.7421 - accuracy: 0.1016 - val_loss: 3.7451 - val_accuracy: 0.0456
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  127
# 4/4 [==============================] - 6s 2s/step - loss: 3.5388 - accuracy: 0.0625 - val_loss: 3.7336 - val_accuracy: 0.0489
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  128
# 4/4 [==============================] - 6s 2s/step - loss: 3.7898 - accuracy: 0.0781 - val_loss: 3.7996 - val_accuracy: 0.0608
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  129
# 4/4 [==============================] - 6s 2s/step - loss: 3.7205 - accuracy: 0.0547 - val_loss: 3.7908 - val_accuracy: 0.0595
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  130
# 4/4 [==============================] - 6s 2s/step - loss: 3.6696 - accuracy: 0.0469 - val_loss: 3.7541 - val_accuracy: 0.0509
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  131
# 4/4 [==============================] - 6s 2s/step - loss: 3.7798 - accuracy: 0.0234 - val_loss: 3.7691 - val_accuracy: 0.0516
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  132
# 4/4 [==============================] - 6s 2s/step - loss: 3.7288 - accuracy: 0.0781 - val_loss: 3.7465 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  133
# 4/4 [==============================] - 6s 2s/step - loss: 3.6960 - accuracy: 0.0703 - val_loss: 3.7584 - val_accuracy: 0.0628
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  134
# 4/4 [==============================] - 6s 2s/step - loss: 3.6726 - accuracy: 0.0859 - val_loss: 3.7397 - val_accuracy: 0.0489
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  135
# 4/4 [==============================] - 6s 2s/step - loss: 3.7355 - accuracy: 0.0703 - val_loss: 3.7600 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  136
# 4/4 [==============================] - 6s 2s/step - loss: 3.9814 - accuracy: 0.0391 - val_loss: 3.7500 - val_accuracy: 0.0562
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  137
# 4/4 [==============================] - 6s 2s/step - loss: 3.7758 - accuracy: 0.0469 - val_loss: 3.7353 - val_accuracy: 0.0608
#
# Epoch 00001: val_loss did not improve from 3.71652
# epoch  138
# 4/4 [==============================] - 6s 2s/step - loss: 3.7934 - accuracy: 0.0312 - val_loss: 3.7115 - val_accuracy: 0.0635
#
# Epoch 00001: val_loss improved from 3.71652 to 3.71148, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  139
# 4/4 [==============================] - 6s 2s/step - loss: 3.7924 - accuracy: 0.0547 - val_loss: 3.7069 - val_accuracy: 0.0589
#
# Epoch 00001: val_loss improved from 3.71148 to 3.70693, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  140
# 4/4 [==============================] - 6s 2s/step - loss: 3.6487 - accuracy: 0.0703 - val_loss: 3.7059 - val_accuracy: 0.0562
#
# Epoch 00001: val_loss improved from 3.70693 to 3.70588, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  141
# 4/4 [==============================] - 6s 2s/step - loss: 3.6981 - accuracy: 0.0625 - val_loss: 3.7297 - val_accuracy: 0.0496
#
# Epoch 00001: val_loss did not improve from 3.70588
# epoch  142
# 4/4 [==============================] - 6s 2s/step - loss: 3.5920 - accuracy: 0.0781 - val_loss: 3.7380 - val_accuracy: 0.0536
#
# Epoch 00001: val_loss did not improve from 3.70588
# epoch  143
# 4/4 [==============================] - 6s 2s/step - loss: 3.7156 - accuracy: 0.0547 - val_loss: 3.7511 - val_accuracy: 0.0529
#
# Epoch 00001: val_loss did not improve from 3.70588
# epoch  144
# 4/4 [==============================] - 6s 2s/step - loss: 3.8199 - accuracy: 0.0469 - val_loss: 3.7330 - val_accuracy: 0.0503
#
# Epoch 00001: val_loss did not improve from 3.70588
# epoch  145
# 4/4 [==============================] - 6s 2s/step - loss: 3.8221 - accuracy: 0.0547 - val_loss: 3.7096 - val_accuracy: 0.0608
#
# Epoch 00001: val_loss did not improve from 3.70588
# epoch  146
# 4/4 [==============================] - 6s 2s/step - loss: 3.7746 - accuracy: 0.0547 - val_loss: 3.7016 - val_accuracy: 0.0569
#
# Epoch 00001: val_loss improved from 3.70588 to 3.70161, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  147
# 4/4 [==============================] - 6s 2s/step - loss: 3.6921 - accuracy: 0.0703 - val_loss: 3.7183 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  148
# 4/4 [==============================] - 6s 2s/step - loss: 3.8196 - accuracy: 0.0391 - val_loss: 3.7146 - val_accuracy: 0.0582
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  149
# 4/4 [==============================] - 6s 2s/step - loss: 3.6599 - accuracy: 0.0703 - val_loss: 3.7174 - val_accuracy: 0.0562
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  150
# 4/4 [==============================] - 6s 2s/step - loss: 3.6138 - accuracy: 0.0391 - val_loss: 3.7097 - val_accuracy: 0.0516
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  151
# 4/4 [==============================] - 6s 2s/step - loss: 3.6826 - accuracy: 0.0625 - val_loss: 3.7180 - val_accuracy: 0.0509
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  152
# 4/4 [==============================] - 6s 2s/step - loss: 3.8306 - accuracy: 0.0391 - val_loss: 3.7044 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  153
# 4/4 [==============================] - 6s 2s/step - loss: 3.7514 - accuracy: 0.0703 - val_loss: 3.7121 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  154
# 4/4 [==============================] - 6s 2s/step - loss: 3.7101 - accuracy: 0.0547 - val_loss: 3.7178 - val_accuracy: 0.0628
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  155
# 4/4 [==============================] - 6s 2s/step - loss: 3.6080 - accuracy: 0.1094 - val_loss: 3.7603 - val_accuracy: 0.0615
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  156
# 4/4 [==============================] - 6s 2s/step - loss: 3.6776 - accuracy: 0.0781 - val_loss: 3.7445 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  157
# 4/4 [==============================] - 6s 2s/step - loss: 3.7444 - accuracy: 0.0781 - val_loss: 3.7717 - val_accuracy: 0.0615
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  158
# 4/4 [==============================] - 6s 2s/step - loss: 3.8454 - accuracy: 0.1016 - val_loss: 3.7594 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  159
# 4/4 [==============================] - 6s 2s/step - loss: 3.6424 - accuracy: 0.1016 - val_loss: 3.7079 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  160
# 4/4 [==============================] - 6s 2s/step - loss: 3.7605 - accuracy: 0.0469 - val_loss: 3.7099 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  161
# 4/4 [==============================] - 6s 2s/step - loss: 3.6550 - accuracy: 0.0625 - val_loss: 3.7170 - val_accuracy: 0.0516
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  162
# 4/4 [==============================] - 6s 2s/step - loss: 3.6341 - accuracy: 0.0703 - val_loss: 3.7226 - val_accuracy: 0.0529
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  163
# 4/4 [==============================] - 6s 2s/step - loss: 3.6422 - accuracy: 0.0703 - val_loss: 3.7186 - val_accuracy: 0.0602
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  164
# 4/4 [==============================] - 6s 2s/step - loss: 3.7120 - accuracy: 0.0391 - val_loss: 3.7296 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  165
# 4/4 [==============================] - 6s 2s/step - loss: 3.6657 - accuracy: 0.0938 - val_loss: 3.7611 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  166
# 4/4 [==============================] - 6s 2s/step - loss: 3.6557 - accuracy: 0.0391 - val_loss: 3.7544 - val_accuracy: 0.0423
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  167
# 4/4 [==============================] - 6s 2s/step - loss: 3.7637 - accuracy: 0.0703 - val_loss: 3.7310 - val_accuracy: 0.0496
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  168
# 4/4 [==============================] - 6s 2s/step - loss: 3.7409 - accuracy: 0.0469 - val_loss: 3.7392 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  169
# 4/4 [==============================] - 6s 2s/step - loss: 3.7574 - accuracy: 0.0781 - val_loss: 3.7148 - val_accuracy: 0.0503
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  170
# 4/4 [==============================] - 6s 2s/step - loss: 3.7890 - accuracy: 0.0234 - val_loss: 3.7079 - val_accuracy: 0.0509
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  171
# 4/4 [==============================] - 6s 2s/step - loss: 3.6234 - accuracy: 0.0859 - val_loss: 3.7164 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  172
# 4/4 [==============================] - 6s 2s/step - loss: 3.7041 - accuracy: 0.0312 - val_loss: 3.7088 - val_accuracy: 0.0615
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  173
# 4/4 [==============================] - 6s 2s/step - loss: 3.7052 - accuracy: 0.0469 - val_loss: 3.7187 - val_accuracy: 0.0608
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  174
# 4/4 [==============================] - 6s 2s/step - loss: 3.6059 - accuracy: 0.1016 - val_loss: 3.7116 - val_accuracy: 0.0562
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  175
# 4/4 [==============================] - 6s 2s/step - loss: 3.7629 - accuracy: 0.0625 - val_loss: 3.7206 - val_accuracy: 0.0569
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  176
# 4/4 [==============================] - 6s 2s/step - loss: 3.6970 - accuracy: 0.0703 - val_loss: 3.7170 - val_accuracy: 0.0536
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  177
# 4/4 [==============================] - 6s 2s/step - loss: 3.7194 - accuracy: 0.0781 - val_loss: 3.7206 - val_accuracy: 0.0496
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  178
# 4/4 [==============================] - 6s 2s/step - loss: 3.6867 - accuracy: 0.0859 - val_loss: 3.7297 - val_accuracy: 0.0483
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  179
# 4/4 [==============================] - 6s 2s/step - loss: 3.7138 - accuracy: 0.0234 - val_loss: 3.7283 - val_accuracy: 0.0476
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  180
# 4/4 [==============================] - 6s 2s/step - loss: 3.8206 - accuracy: 0.0547 - val_loss: 3.7314 - val_accuracy: 0.0443
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  181
# 4/4 [==============================] - 6s 2s/step - loss: 3.7751 - accuracy: 0.0625 - val_loss: 3.7082 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  182
# 4/4 [==============================] - 6s 2s/step - loss: 3.6080 - accuracy: 0.0312 - val_loss: 3.7031 - val_accuracy: 0.0509
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  183
# 4/4 [==============================] - 6s 2s/step - loss: 3.6122 - accuracy: 0.0938 - val_loss: 3.7180 - val_accuracy: 0.0569
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  184
# 4/4 [==============================] - 6s 2s/step - loss: 3.5686 - accuracy: 0.0781 - val_loss: 3.7212 - val_accuracy: 0.0529
#
# Epoch 00001: val_loss did not improve from 3.70161
# epoch  185
# 4/4 [==============================] - 6s 2s/step - loss: 3.5891 - accuracy: 0.0781 - val_loss: 3.6969 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss improved from 3.70161 to 3.69689, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  186
# 4/4 [==============================] - 6s 2s/step - loss: 3.6857 - accuracy: 0.0703 - val_loss: 3.6986 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss did not improve from 3.69689
# epoch  187
# 4/4 [==============================] - 6s 2s/step - loss: 3.6434 - accuracy: 0.0703 - val_loss: 3.6795 - val_accuracy: 0.0582
#
# Epoch 00001: val_loss improved from 3.69689 to 3.67947, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  188
# 4/4 [==============================] - 6s 2s/step - loss: 3.5995 - accuracy: 0.0781 - val_loss: 3.7187 - val_accuracy: 0.0602
#
# Epoch 00001: val_loss did not improve from 3.67947
# epoch  189
# 4/4 [==============================] - 6s 2s/step - loss: 3.6697 - accuracy: 0.0391 - val_loss: 3.7118 - val_accuracy: 0.0595
#
# Epoch 00001: val_loss did not improve from 3.67947
# epoch  190
# 4/4 [==============================] - 6s 2s/step - loss: 3.6813 - accuracy: 0.0391 - val_loss: 3.7075 - val_accuracy: 0.0608
#
# Epoch 00001: val_loss did not improve from 3.67947
# epoch  191
# 4/4 [==============================] - 6s 2s/step - loss: 3.6426 - accuracy: 0.0859 - val_loss: 3.7130 - val_accuracy: 0.0595
#
# Epoch 00001: val_loss did not improve from 3.67947
# epoch  192
# 4/4 [==============================] - 6s 2s/step - loss: 3.5395 - accuracy: 0.1016 - val_loss: 3.7118 - val_accuracy: 0.0595
#
# Epoch 00001: val_loss did not improve from 3.67947
# epoch  193
# 4/4 [==============================] - 6s 2s/step - loss: 3.7030 - accuracy: 0.0547 - val_loss: 3.6951 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss did not improve from 3.67947
# epoch  194
# 4/4 [==============================] - 6s 2s/step - loss: 3.7460 - accuracy: 0.0469 - val_loss: 3.6892 - val_accuracy: 0.0569
#
# Epoch 00001: val_loss did not improve from 3.67947
# epoch  195
# 4/4 [==============================] - 6s 2s/step - loss: 3.7126 - accuracy: 0.0625 - val_loss: 3.7073 - val_accuracy: 0.0536
#
# Epoch 00001: val_loss did not improve from 3.67947
# epoch  196
# 4/4 [==============================] - 6s 2s/step - loss: 3.7596 - accuracy: 0.0469 - val_loss: 3.7143 - val_accuracy: 0.0582
#
# Epoch 00001: val_loss did not improve from 3.67947
# epoch  197
# 4/4 [==============================] - 6s 2s/step - loss: 3.5864 - accuracy: 0.0938 - val_loss: 3.7199 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss did not improve from 3.67947
# epoch  198
# 4/4 [==============================] - 6s 2s/step - loss: 3.7309 - accuracy: 0.0547 - val_loss: 3.7129 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss did not improve from 3.67947
# epoch  199
# 4/4 [==============================] - 6s 2s/step - loss: 3.5649 - accuracy: 0.0391 - val_loss: 3.7428 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss did not improve from 3.67947

# %% [markdown]
# ---

# %% [markdown]
# ##**5.4 Model Performance**
#
# We will assess the performance of the model by plotting the **validation set loss versus the training set loss**. If the performance of the training set improves too fast and diverges from the validation set, this is a sign of overfitting. Our objective is to prevent overfitting, thus making the model more robust to unseen data.

# %%
# plot training loss vs. validation loss over epochs
val_loss_change = []; loss_change = []
for i in range(0, epochs):
    val_loss_change.append(history.history['val_loss'][i])
    loss_change.append(history.history['loss'][i])

plt.plot(val_loss_change, label='val_loss')
plt.plot(loss_change, label='train_loss')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# We will also assess the performance of the model by plotting the **validation set accuracy versus the training set accuracy**.

# %%
# plot training loss vs. validation loss over epochs
val_accuracy_change = []; accuracy_change = []
for i in range(0, epochs):
    val_accuracy_change.append(history.history['val_accuracy'][i])
    accuracy_change.append(history.history['accuracy'][i])

plt.plot(val_accuracy_change, label='val_accuracy')
plt.plot(accuracy_change, label='train_accuracy')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# **Check the training set loss and accuracy.**

# %%
# loss and accuracy on training set
train_eval = age_model.evaluate(train_x, train_y, verbose=1, batch_size=128, return_dict=True)
train_eval
# Out:
# 28/28 [==============================] - 27s 526ms/step - loss: 3.4739 - accuracy: 0.0811
# {'accuracy': 0.08113475143909454, 'loss': 3.4739279747009277}

# %% [markdown]
# **Check the test set loss and accuracy.**

# %%
# loss and accuracy on test set
test_eval = age_model.evaluate(test_x, test_y, verbose=1, batch_size=128, return_dict=True)
test_eval
# Out:
# 12/12 [==============================] - 13s 1s/step - loss: 3.6795 - accuracy: 0.0582
# {'accuracy': 0.05820105969905853, 'loss': 3.6794660091400146}

# %% [markdown]
# **Predictions on the test set.**

# %%
predictions = age_model.predict(test_x)

# %% [markdown]
# **The array of predictions need to be decoded into predicted ages.**

# %%
output_indexes = np.array([i for i in range(8, 81)])
apparent_predictions = np.sum(predictions * output_indexes, axis = 1)

# %% [markdown]
# **Let's take a look at the maximum, minimum and mean age predictions to ensure that our distribution of values is what we expected.**

# %%
prediction_list = []
for i in range(73):
  prediction_list.append((np.argmax(predictions[i] * output_indexes[i])+8))

print("Minumum Predicted Age:",min(prediction_list))
print("Maximum Predicted Age:",max(prediction_list))
print("Average Predicted Age:",np.mean(prediction_list))
# Out:
# Minumum Predicted Age: 8
# Maximum Predicted Age: 80
# Average Predicted Age: 43.56164383561644

# %% [markdown]
# **Mean Absolute Error**
#
# Compute the Mean Absolute Error (MAE) to see how far the predicted ages are from the actual ages on average. MAE is the primary performance metric of our project.

# %%
# compute mae
mae_sum = 0
errors = []
n = apparent_predictions.shape[0]
prediction_list = []
for i in range(n):
    prediction = apparent_predictions[i]
    actual = np.argmax(test_y[i]) + 8
    mae_sum += abs(actual  - prediction)

    prediction_list.append(int(apparent_predictions[i])) # create a prediction list to plot
    errors.append((np.argmax(test_y[i]) + 8) - apparent_predictions[i])

mae = mae_sum / n
print("mae: ",mae)
print("instances: ", n)
# Out:
# mae:  7.426888423423361
# instances:  1512

# %%
# visualize the actual vs predicted age error distribution 
positive_errors = [i for i in errors if i > 0]
negative_errors = [i for i in errors if i < 0]

fig, ax = plt.subplots(figsize=(5,5))
sns.set_theme(style="darkgrid")
sns.histplot(positive_errors, color='blue', alpha=.8)
sns.histplot(negative_errors, color='red', alpha=.8)
plt.title('Error Distribution')
plt.xlabel('Error');

# %%
# Let's assume a Gaussian distribution of the errors
errors_mean = np.mean(errors)
errors_std = np.std(errors)
positive_std   = np.mean(errors) + np.std(errors) 
positive_std2  = np.mean(errors) + np.std(errors)*2
positive_std3  = np.mean(errors) + np.std(errors)*3
negative_std   = np.mean(errors) - np.std(errors)
negative_std2  = np.mean(errors) - np.std(errors)*2
negative_std3  = np.mean(errors) - np.std(errors)*3

print("Errors: Mean:",errors_mean)
print("Errors: Standard Deviation:",errors_std)
print("Errors: 1 Positive Standard Deviation: ",positive_std)
print("Errors: 2 Positive Standard Deviation: ",positive_std2)
print("Errors: 3 Positive Standard Deviation: ",positive_std3)
print("Errors: 1 Negative Standard Deviation:",negative_std)
print("Errors: 2 Negative Standard Deviation:",negative_std2)
print("Errors: 3 Negative Standard Deviation:",negative_std3)
# Out:
# Errors: Mean: -0.06975802978259113
# Errors: Standard Deviation: 10.488774396337949
# Errors: 1 Positive Standard Deviation:  10.419016366555358
# Errors: 2 Positive Standard Deviation:  20.907790762893306
# Errors: 3 Positive Standard Deviation:  31.396565159231255
# Errors: 1 Negative Standard Deviation: -10.55853242612054
# Errors: 2 Negative Standard Deviation: -21.047306822458488
# Errors: 3 Negative Standard Deviation: -31.536081218796436

# %%
# 68, 95, 99.7 = "three-sigma rule" AKA empirical rule for normal distributions
print("~ 68%   prediction errors from",round(negative_std,2),'to',round(positive_std,2))
print("~ 95%   prediction errors from",round(negative_std2,2),'to',round(positive_std2,2))
print("~ 99.7% prediction errors from",round(negative_std3,2),'to',round(positive_std3,2))
# Out:
# ~ 68%   prediction errors from -10.56 to 10.42
# ~ 95%   prediction errors from -21.05 to 20.91
# ~ 99.7% prediction errors from -31.54 to 31.4

# %%
# # visualize the actual vs predicted age error distribution with standard deviations as x ticks

fig, ax = plt.subplots(figsize=(5,5))
sns.set_theme(style="darkgrid")
sns.histplot(positive_errors, color='blue', alpha=.8)
sns.histplot(negative_errors, color='red', alpha=.8)
plt.title('Error Distribution')
plt.xlabel('Error')
ticky = [negative_std3, negative_std2, negative_std, errors_mean, positive_std, positive_std2, positive_std3]
tacky = ['-3σ','-2σ','-1σ','|','1σ','2σ','3σ']
plt.xticks(ticky, tacky);

# %% [markdown]
# **Mean Absolute Percentage Error**
#
# Compute the Mean Absolute Percentage Error (MAPE) to see how far the predicted ages are from the actual ages on average as a percentage.

# %%
# create list 'test_y_age'  of the actual age labels
test_y_age = np.argmax(test_y, axis=1)

# ADD 8 to the test_y labels. 8 was subtracted for one-hot categorical encoding
test_y_age = test_y_age + 8

# %%
# calculate MAPE
mape_sum = 0
n = apparent_predictions.shape[0]
for i in range(n): 
  mape_sum += (abs((test_y_age[i]) - (apparent_predictions[i]))/(test_y_age[i]))
mape = (mape_sum/n) 

print(mape)
print('MAPE:',(round(mape*100,2)),"%")
# Out:
# 0.24980058614255304
# MAPE: 24.98 %

# %% [markdown]
# ---

# %% [markdown]
# ##**5.5 Performance Visualization**
#
# Let's create data visualizations to compare the predicted ages with the actual ages. We will create a few to survey which data visualization is the most useful for analysis.

# %%
# plot a scatterplot with a 'perfect prediction' line
sns.set_theme(style="darkgrid")
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(test_y_age, apparent_predictions)
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=3)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Observation:** Above, we can see the 'perfect prediction' dotted line and get a general sense of the error pattern in the system. Generally, there is a positive correlation between actual age and predicted age. We can also see some predictions far from the ideal line.

# %%
# jointplot - scatterplot with histogram
sns.jointplot(test_y_age, apparent_predictions)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Correlation**
#
# Check Pearson Correlation Coefficient between predicted ages and actual ages.

# %%
# corr(test_y_age, apparent_predictions)
np.corrcoef(test_y_age, apparent_predictions)
# Out:
# array([[1.        , 0.86703053],
#        [0.86703053, 1.        ]])

# %% [markdown]
# **Confusion Matrix**
#
# We will create and plot a Confusion Matrix to visualize prediction accuracy in a grid.

# %%
# confusion_matrix
from sklearn.metrics import confusion_matrix
import itertools
sns.set_theme(style='dark')
# prediction_list = np.array(prediction_list) + 8
conf_mat1 = confusion_matrix(test_y_age, prediction_list)

# %%
# plot the confusion matrix 
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', export_as='confusion_matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, cmap=cmap, interpolation='nearest')
    plt.title(title, fontsize=22)
    plt.colorbar()
    a_list = list(range(73))
    b_list = [8,'',10,'','','','',15,'','','','',20,'','','','',25,'','','','',30,'','','','',35,'','','','',40,'','','','',\
                   45,'','','','',50,'','','','',55,'','','','',60,'','','','',65,'','','','',70,'','','','',75 ,'','','','',80]
    plt.xticks(a_list, b_list, fontsize=12)
    plt.yticks(a_list, b_list, fontsize=12)

    plt.tight_layout()
    plt.ylabel('Predicted Age', fontsize=18)
    plt.xlabel('Actual Age', fontsize=18)
    plt.savefig('/content/drive/MyDrive/YOUNGER/conf_mat1.png');

# %%
plt.figure(figsize=(10,10))
plot_confusion_matrix(conf_mat1, list(range(73)), normalize=False,
                      title="Confusion Matrix: Age Prediction, CNN Model 1")
plt.show()

# %% [markdown]
# **Observation:**
# Again, we can see the correlation trend forming a linear shape. Perfect predictions would form a dark blue line from top-left to bottom-right. The predictions are far from perfect.
#
# **Best Predictions, Decent Predicitions, Poor Predictions**
#
# Clearly, the predictor predicts better at certain ages than other ages.
#
# The predictor is most accurate at ages: 8, 9, 11-14, 16 and 73.
#
#
# The predictor is somewhat accurate at ages: 14, 17, 25, 30, 31, 34, 36, 39, 40, 42, 45, 46, 49, 53, 56, 58, 63, 67, 70, 72, 73.
#
# The predictor predicts poorly at ages: 35, 43, 48, and 65.

# %%
from sklearn.metrics import classification_report
targets = np.arange(8,81)
apparent_pred_integers = [round(i) for i in apparent_predictions]
classy = classification_report(test_y_age, apparent_pred_integers, zero_division = 0, labels=targets)
print(classy);
# Out:
#               precision    recall  f1-score   support
#
#            8       0.00      0.00      0.00        20
#            9       0.25      0.05      0.08        21
#           10       0.00      0.00      0.00        20
#           11       0.00      0.00      0.00        21
#           12       0.08      0.05      0.06        21
#           13       0.25      0.10      0.14        21
#           14       0.07      0.05      0.06        21
#           15       0.00      0.00      0.00        20
#           16       0.17      0.14      0.15        21
#           17       0.08      0.05      0.06        20
#           18       0.06      0.05      0.05        21
#           19       0.10      0.05      0.06        21
#           20       0.00      0.00      0.00        21
#           21       0.00      0.00      0.00        21
#           22       0.07      0.10      0.08        21
#           23       0.15      0.25      0.19        20
#           24       0.00      0.00      0.00        21
#           25       0.00      0.00      0.00        20
#           26       0.17      0.19      0.18        21
#           27       0.07      0.10      0.08        21
#           28       0.08      0.10      0.09        21
#           29       0.00      0.00      0.00        21
#           30       0.07      0.10      0.08        20
#           31       0.00      0.00      0.00        21
#           32       0.00      0.00      0.00        21
#           33       0.06      0.10      0.08        21
#           34       0.03      0.05      0.04        21
#           35       0.00      0.00      0.00        20
#           36       0.03      0.05      0.04        21
#           37       0.03      0.05      0.04        21
#           38       0.00      0.00      0.00        21
#           39       0.04      0.05      0.04        21
#           40       0.00      0.00      0.00        21
#           41       0.00      0.00      0.00        20
#           42       0.00      0.00      0.00        21
#           43       0.00      0.00      0.00        21
#           44       0.04      0.05      0.04        21
#           45       0.23      0.29      0.26        21
#           46       0.00      0.00      0.00        20
#           47       0.12      0.10      0.11        20
#           48       0.00      0.00      0.00        21
#           49       0.10      0.10      0.10        20
#           50       0.00      0.00      0.00        21
#           51       0.15      0.14      0.15        21
#           52       0.00      0.00      0.00        20
#           53       0.00      0.00      0.00        21
#           54       0.00      0.00      0.00        21
#           55       0.05      0.05      0.05        21
#           56       0.06      0.05      0.05        21
#           57       0.05      0.05      0.05        21
#           58       0.00      0.00      0.00        20
#           59       0.05      0.05      0.05        21
#           60       0.05      0.05      0.05        21
#           61       0.05      0.05      0.05        21
#           62       0.06      0.10      0.08        20
#           63       0.00      0.00      0.00        21
#           64       0.05      0.05      0.05        21
#           65       0.00      0.00      0.00        21
#           66       0.04      0.05      0.04        21
#           67       0.04      0.05      0.04        21
#           68       0.03      0.05      0.04        20
#           69       0.07      0.10      0.08        21
#           70       0.03      0.05      0.04        20
#           71       0.08      0.10      0.09        20
#           72       0.00      0.00      0.00        21
#           73       0.10      0.14      0.12        21
#           74       0.11      0.10      0.10        21
#           75       0.00      0.00      0.00        20
#           76       0.00      0.00      0.00        20
#           77       0.00      0.00      0.00        21
#           78       0.00      0.00      0.00        21
#           79       0.00      0.00      0.00        21
#           80       0.00      0.00      0.00        20
#
#     accuracy                           0.05      1512
#    macro avg       0.05      0.05      0.04      1512
# weighted avg       0.05      0.05      0.04      1512

# %% [markdown]
# ---

# %% [markdown]
# ##**5.6 Unseen Data Test**
#
# We will create a sequence to predict the ages of new images loaded through Google Drive and also images from on the Internet.
#
# We can imagine this being the "app" where a user inputs their photo and the app returns an age prediction. This is the practical application of the predictor.
#
# **There are 2 predictions.** Prediction 1 is the highest probability prediction and Prediction 2 is the average of the top 5 highest probability predictions.
#
# "Actual Ages" are based on the date the images were captured verified by cross-checking Getty Images for the celebrities.

# %%
# image preprocessing
def loadImage(filepath):
    test_img = image.load_img(filepath, target_size=(224, 224))
    test_img = image.img_to_array(test_img)
    test_img = np.expand_dims(test_img, axis = 0)
    test_img /= 255
    return test_img

# %%
# predictor function using the model created above
from keras.preprocessing import image
sns.set_theme(style='dark')

def image_age(photo):
  prediction2 = age_model.predict(loadImage(photo))
  img = image.load_img(photo)#, target_size=(224, 224))
  plt.xticks([], []), ax.set_xticks([]), plt.yticks([], []), ax.set_yticks([]) # clear x & y ticks
  plt.imshow(img)   # display image
  plt.show()
  
  # print("Predicted Age: ", (np.argmax(prediction))+8)
  apparent_age = np.round(np.sum(prediction2 * output_indexes, axis=1))
  print(" Predicted Age: ", int(apparent_age[0]))
  print(" Average Top 5: ",round(np.mean(np.argsort(prediction2[0])[-5:])+8))
  print(" ------------------")

# %%
# visualize probabilites of each age class
def viz_prob(pic):
  prediction_1 = age_model.predict(loadImage(pic))
  y_pos = np.arange(73)+8
  plt.bar(y_pos, prediction_1[0], align='center', alpha=0.8)
  plt.ylabel('predicted probability')
  plt.xlabel('age')
  plt.title('Age Prediction Probabilities')
  plt.show()

# %% [markdown]
# **Load New Image, Predict Age, Visualize Probabilites**

# %%
# insert image (of me) from Google Drive by path
picture1 = "/content/drive/MyDrive/YOUNGER/prem_linked.jpg"
image_age(picture1)
print(' Actual Age:     35')
viz_prob(picture1)
# Out:
#  Predicted Age:  37
#  Average Top 5:  38
#  ------------------
#  Actual Age:     35

# %%
picture2 = '/content/drive/MyDrive/YOUNGER/harrison_ford_70.jpg'
image_age(picture2)
print(' Actual Age:     70')
viz_prob(picture2)
# Out:
#  Predicted Age:  70
#  Average Top 5:  74
#  ------------------
#  Actual Age:     70

# %%
# create a web image upload & predict sequence
from PIL import Image
import requests

def web_age(url):  
  web_photo = Image.open(requests.get(url, stream=True).raw).save("web_photo.jpg")
  picture1 = "/content/web_photo.jpg"
  image_age(picture1)
  # viz_prob(picture1)

# %%
url = "https://media.allure.com/photos/5e8359941cb813000841fb8b/3:2/w_3000,h_2000,c_limit/celine%20dion.jpg"
web_age(url)
print(' Actual Age:     52')
# Out:
#  Predicted Age:  61
#  Average Top 5:  61
#  ------------------
#  Actual Age:     52

# %%
url = 'https://assets.vogue.com/photos/5e6f950f5530ac0009b932fb/1:1/w_3538,h_3538,c_limit/GettyImages-1205201930.jpg'
web_age(url)
print(' Actual Age:     63')
# Out:
#  Predicted Age:  62
#  Average Top 5:  63
#  ------------------
#  Actual Age:     63

# %%
url = 'https://media.gettyimages.com/photos/tom-hanks-attends-the-92nd-annual-academy-awards-at-hollywood-and-on-picture-id1205142068?s=2048x2048'
web_age(url)
print(' Actual Age:     63')
# Out:
#  Predicted Age:  64
#  Average Top 5:  68
#  ------------------
#  Actual Age:     63

# %% [markdown]
# The prediction is better for the image that is tightly cropped. The predictor was trained on images with a specific 40% margin, tightly cropped. We can expect that the predictor would perform better on images similar to the training set.
#
# One possible method to improve performance on unseen data is to have the system pre-process new images by cropping them with the correct margin and image size.

# %%
url = 'https://static.wikia.nocookie.net/euphoria-hbo/images/5/5c/Zendaya.jpg/revision/latest?cb=20190601162350'
web_age(url)
print(' Actual Age:     20')
# Out:
#  Predicted Age:  21
#  Average Top 5:  20
#  ------------------
#  Actual Age:     20

# %%
url = 'https://media.gettyimages.com/photos/zendaya-attends-the-rei-kawakubocomme-des-garcons-art-of-the-costume-picture-id675901048?s=2048x2048'
web_age(url)
print(' Actual Age:     20')
# Out:
#  Predicted Age:  47
#  Average Top 5:  47
#  ------------------
#  Actual Age:     20

# %% [markdown]
# Above, the same person, Zendaya, at the same age is predicted well, and then predicted poorly. Perhaps the unique hair feature is being read as wrinkles. Perhaps frizzy hair is associated with older people.

# %%
url = 'https://i.guim.co.uk/img/media/7f2b972fa41cd4d26a3620cea335aad33cde6c32/0_127_3500_2101/master/3500.jpg?width=445&quality=45&auto=format&fit=max&dpr=2&s=02571424bc9abc13340589ef47eb7b0b'
web_age(url)
print(' Actual Age:     34')
# Out:
#  Predicted Age:  36
#  Average Top 5:  37
#  ------------------
#  Actual Age:     34

# %%
url = 'https://static.wikia.nocookie.net/harrypotter/images/9/97/Harry_Potter.jpg/revision/latest?cb=20140603201724'
web_age(url)
print(' Actual Age:     20')
# Out:
#  Predicted Age:  29
#  Average Top 5:  13
#  ------------------
#  Actual Age:     20

# %%
url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRed4B_N95FjRE0a-2sn3OEXAjc0SkMkWeJTQ&usqp=CAU'
web_age(url)
print(' Actual Age:     48')
# Out:
#  Predicted Age:  50
#  Average Top 5:  47
#  ------------------
#  Actual Age:     48

# %% [markdown]
# ---

# %% [markdown]
# # **VI. SUMMARY**

# %% [markdown]
# Well, that was a lot. Let's take a look at what this notebook covers.
#
# **Preprocessing**
#
# During preprocessing, we loaded and prepared the data for machine learning by one-hot encoding the target classes. We scaled the pixel values from 0-255 to 0-1. We also split the data into training and testing subsets.
#
# **Modeling**
#
# Onward to modeling, we used a proven model arcitecture with pretrained weights for the first layers to expedite our learning. By using transfer learning we were able to use the existing model weights that have been previously trained on a massive 2.6 million image dataset. We froze the early layers and focuses on training the later layers in the model. Next we trained the model, observed results of the training, and reset the batchsize and the number of epochs to achieve a reasonable learning rate without overfitting.
#
# **Metrics**
#
# Our primary model performance metric is validation loss. We created our model to train to minimize validation loss and save the best weights progressively. We eventually got down to a reasonable validation loss for this project.
#
# Our primary overall metric is Mean Absolute Error (MAE). We want to minimize how far our predicted are from the actual ages. So far our MAE is still far from ideal. Training on a lot more data will help.
#
# **Visualizations**
#
# We created a confusion matrix, a scatterplot and a jointplot to get a sense of how well the model is predicting. Overall, the general trend is positive but there is room for improvement.
#
# **Unseen Data**
#
# We created a small program to predict the ages for new images from Google Drive and from the Internet. The results were encouraging.

# %% [markdown]
# ---

# %%
# one for the road
url = 'https://imagesvc.meredithcorp.io/v3/mm/image?q=85&c=sc&poi=face&w=1200&h=1600&url=https%3A%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F20%2F2019%2F05%2Fkim-beauty.jpg'
web_age(url)
print(' Actual Age:     37')
# Out:
#  Predicted Age:  31
#  Average Top 5:  28
#  ------------------
#  Actual Age:     37

# %% [markdown]
# ---

# %% [markdown]
# # **VII. REFERENCES**

# %% [markdown]
# 1.   https://data.vision.ee.ethz.ch/cvl/rrothe/imdb-wiki/
# 2.   https://data.vision.ee.ethz.ch/cvl/publications/papers/proceedings/eth_biwi_01229.pdf
# 3. https://sefiks.com/2019/02/13/apparent-age-and-gender-prediction-in-keras/
# 4. https://www.researchgate.net/publication/265125544_Face_Detection_without_Bells_and_Whistles
# 5. https://github.com/yu4u/age-gender-estimation
# 6. https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf
# 7. https://link.springer.com/chapter/10.1007/978-3-319-10593-2_47
#
#
# ---

# %% [markdown]
# # **VIII. APPENDIX**

# %% [markdown]
# **Model Summary**
#
# [VGG-Face Model](https://https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf) was the basis for our model. We used the VGG-Face structure and trained on the last 4 custom layers.

# %%
age_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_input (InputLayer [(None, 224, 224, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 226, 226, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 226, 226, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 114, 114, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 114, 114, 128)     0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 58, 58, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# zero_padding2d_5 (ZeroPaddin (None, 58, 58, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# zero_padding2d_6 (ZeroPaddin (None, 58, 58, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# zero_padding2d_7 (ZeroPaddin (None, 30, 30, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 30, 30, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 30, 30, 512)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# zero_padding2d_10 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# zero_padding2d_11 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# zero_padding2d_12 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 1, 4096)        102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 1, 4096)        16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 4096)        0
# _________________________________________________________________
# predictions (Dense)          (None, 1, 1, 73)          299081
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 73)                0
# _________________________________________________________________
# dense (Dense)                (None, 73)                5402
# =================================================================
# Total params: 134,565,027
# Trainable params: 119,850,339
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ---

# %% [markdown]
# **TensorBoard**
# TensorBoard visualization for experimentation.

# %%
# !kill 380
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 423), started 3:52:23 ago. (Use '!kill 423' to kill it.)

# %%
# !tensorboard dev upload \
#   --logdir logs/fit \
#   --name "My latest experiment" \
#   --description "Simple comparison of hyperparameters" \
#   --one_shot

# %% [markdown]
# [TensorBoard for this Notebook](https://tensorboard.dev/experiment/v5YLmltjR3aPCvDj4UvOWQ/#histograms&run=20210512-234228%2Ftrain)

# %% [markdown]
# ---
